# %%
# !pip install top2vec
# !pip install top2vec[sentence_encoders]

# %% [markdown]
# This project used multiple Python libraries in its different stages of web scraping, preprocessing, and in performing a search. The preprocessing step, necessary to get coherent topics through “Top2Vec”, employed “nltk”, regular expressions (“re”) and “string” to normalize, tokenize and exclude stopwords from the preprocessed text. The project also used nltk’s WordNet functions to expand search queries as well as “cv2” and “matplotlib” to visualize images.

# %%
import string
import re
from nltk.corpus import stopwords
from IPython.display import display
import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
import ast
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import cv2 as cv
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from top2vec import Top2Vec
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The website scraping produced a dataset of 6112 artworks, although not all of them have comprehensive metadata since some were not on sale, lacked descriptions, styles or dimensions, with few only having their title and artist. After scraping the two websites, and obtaining from the artworks the desired metadata, when available, the two datasets were opened into the notebook (as the scraping code was not run on it) and went through preprocessing to convert the dimensions and prices into just numbers and making sure the two were ready to be merged. For instance, the two raw datasets had different names for the column indicating the image path, which was fixed in this step. Moreover, prices under 100 dollars were removed from the Artmajeur dataset as in most cases they referred to the prices of digital licensing or print reproductions and not of the artwork itself. Subsequently to this preprocessing, the datasets were then merged.

# %%
# Load the dataset obtained through the previous code cells
anasaea = pd.read_csv('/content/drive/MyDrive/Uni/Digital Humanities Lab/digital humanities lab/raw datasets/anasaea.csv', encoding='utf-8')

# Anasaea preprocessing
anasaea.rename(columns={"Image Path": "Image"}, inplace=True)

# These three functions get the dimensions of the artwork through a regular expression
# and respectively return the dimensions in cm2, height and width
def dimensionstocm2(dimensions):
  regex = r"Height (\d+)cm, Width (\d+)cm"
  if type(dimensions) == str:
    match = re.match(regex, dimensions)
    if match:
      height = match.group(1).strip()
      width = match.group(2).strip()
      finaldimensions = float(height)*float(width)
      return finaldimensions

def height(dimensions):
  regex = r"Height (\d+)cm, Width (\d+)cm"
  if type(dimensions) == str:
    match = re.match(regex, dimensions)
    if match:
      height = match.group(1).strip()
      return height

def width(dimensions):
  regex = r"Height (\d+)cm, Width (\d+)cm"
  if type(dimensions) == str:
    match = re.match(regex, dimensions)
    if match:
      width = match.group(2).strip()
      return width

# Convert string into integers
def convertprices(price):
  try:
    intprice = int(price[1:])
  except:
    intprice = ""
  return intprice

# Apply functions to the Dataframe
anasaea['Height'] = anasaea['Dimensions'].apply(height)
anasaea['Width'] = anasaea['Dimensions'].apply(width)
anasaea['Dimensions in cm2'] = anasaea['Dimensions'].apply(dimensionstocm2)
anasaea['Price'] = anasaea['Price'].apply(convertprices)

# %%
# Load the dataset obtained through the scraping code cells
artmajeur = pd.read_csv('/content/drive/MyDrive/Uni/Digital Humanities Lab/digital humanities lab/raw datasets/artmajeur.csv', encoding='utf-8')

# Artmajeur preprocessing

# Remove the text after the artwork's description since it goes into details about
# general stylistic explanations that are not relevant to the single artwork
def removeabout(description):
  description = description.split('About this artwork:')
  description = description[0]
  return description

# These three functions get the dimensions of the artwork through a regular expression
# and respectively return the dimensions in cm2, height and width
def dimensionstocm2(dimensions):
  regex = r"(\d+)x(\d+) cm"
  if type(dimensions) == str:
    match = re.match(regex, dimensions)
    if match:
      height = match.group(1).strip()
      width = match.group(2).strip()
      finaldimensions = float(height)*float(width)
      return finaldimensions

def height(dimensions):
  regex = r"(\d+)x(\d+) cm"
  if type(dimensions) == str:
    match = re.match(regex, dimensions)
    if match:
      height = match.group(1).strip()
      return height

def width(dimensions):
  regex = r"(\d+)x(\d+) cm"
  if type(dimensions) == str:
    match = re.match(regex, dimensions)
    if match:
      width = match.group(2).strip()
      return width

# Remove prices under 100 as most of them are not for art sale,
# but for the sale of art prints or licensed use.
def removelicenseprices(price):
  try:
    if float(price) < 100:
      price = ""
    else:
      price = float(price)
  except:
    price = price
  return price


def normalizethemes(themes):
  if type(themes) == str:
    themes = ast.literal_eval(themes)
    themes = (" ".join(themes)).lower()
  else:
    themes = themes
  return themes

# Apply functions to the Dataframe
artmajeur['Description'] = artmajeur['Description'].apply(removeabout)
artmajeur['Height'] = artmajeur['Dimensions'].apply(height)
artmajeur['Width'] = artmajeur['Dimensions'].apply(width)
artmajeur['Dimensions in cm2'] = artmajeur['Dimensions'].apply(dimensionstocm2)
artmajeur['Price'] = artmajeur['Price'].apply(removelicenseprices)
artmajeur['Themes'] = artmajeur['Themes'].apply(normalizethemes)

# %%
# Merge the two Dataframes into one
df = pd.concat([anasaea, artmajeur], ignore_index=True)

# %%
df
# Out:
#                              Title              Artist   Price  \
# 0           Zebra underwater No. 2     Shari Blackwell      60
# 1                      Fokker DR I  Constantin Baghici
# 2                          Dreamer         Mistake Ann
# 3                     Pedro Pascal  Antonella Torquati     650
# 4                   Softly Sunrise      Joseph Liberti     400
# ...                            ...                 ...     ...
# 6107    Zeitlose Eleganz: Ein Hase     Birgit Wichmann
# 6108                    Temptation        Lorraine Lyn
# 6109                 Amy Winehouse           Whiteline     NaN
# 6110       Fiat 126P C64 Pixel Art                Rm64  159.99
# 6111  Jesus Escape From Guantanamo    Cristiano Bocchi  273.97
#
#                                             Description  \
# 0     digital art, watermark will be removed upon pu...
# 1     The scene of a combat clash with the participa...
# 2     When I was a child, I liked to run away from h...
# 3     I portrayed him for my daughter :) // This pai...
# 4     Sunrise softly tears the sky on Colorado.\n\nF...
# ...                                                 ...
# 6107  Die Zeichnung zeigt einen Hasen in einer leben...
# 6108  Can you resist the temptation?The beauty desir...
# 6109  Amy Winehouse était une chanteuse et compositr...
# 6110
# 6111  I put the title inside the work, precisely so ...
#
#                    Dimensions                   Style  \
# 0                         NaN              Modern art
# 1                         NaN              Classicism
# 2                         NaN              Surrealism
# 3     Height 40cm, Width 40cm        Contemporary art
# 4     Height 71cm, Width 71cm  Abstract expressionism
# ...                       ...                     ...
# 6107                      NaN              Figurative
# 6108                      NaN           Expressionism
# 6109                      NaN                     NaN
# 6110                      NaN              Minimalism
# 6111                 40x40 cm          Conceptual Art
#
#                                                    Link  \
# 0     https://anasaea.com/viewArtPiece/wFJmgvhhAstnd...
# 1     https://anasaea.com/viewArtPiece/CzpXJcBTZLkZG...
# 2     https://anasaea.com/viewArtPiece/Dubg6zfsEy6hi...
# 3     https://anasaea.com/viewArtPiece/MiuSEBy6KeFLw...
# 4     https://anasaea.com/viewArtPiece/cozFLQpCp4L22...
# ...                                                 ...
# 6107  https://www.artmajeur.com/birgit-wichmann/en/a...
# 6108  https://www.artmajeur.com/lorrainelyn/en/artwo...
# 6109  https://www.artmajeur.com/whiteline/en/artwork...
# 6110  https://www.artmajeur.com/rm64/en/artworks/173...
# 6111  https://www.artmajeur.com/cristiano-bocchi/en/...
#
#                                                   Image Height Width  \
# 0      downloaded_images/wFJmgvhhAstndrvHt_pic1024.jpeg   None  None
# 1      downloaded_images/CzpXJcBTZLkZG6pDW_pic1024.jpeg   None  None
# 2      downloaded_images/Dubg6zfsEy6hijoBa_pic1024.jpeg   None  None
# 3      downloaded_images/MiuSEBy6KeFLwAaQt_pic1024.jpeg     40    40
# 4      downloaded_images/cozFLQpCp4L22yaTg_pic1024.jpeg     71    71
# ...                                                 ...    ...   ...
# 6107  downloaded_images/17674213_default-create-a-pe...   None  None
# 6108          downloaded_images/16794052_temptation.jpg   None  None
# 6109  downloaded_images/17415298_amy-winehouse-conve...   None  None
# 6110  downloaded_images/17320972_maluch-3200-chbrgri...   None  None
# 6111     downloaded_images/17464624_jesu-guantanamo.jpg     40    40
#
#       Dimensions in cm2                                             Themes
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                1600.0                                                NaN
# 4                5041.0                                                NaN
# ...                 ...                                                ...
# 6107                NaN                 aquarell tierzeichnung naturwunder
# 6108                NaN  digitalart aiart desire temptation tentazione ...
# 6109                NaN
# 6110                NaN  fiat 126 pixel pixelart commodore polish retro...
# 6111             1600.0  revolution jesus guantanamo fucine del naro ai...
#
# [6112 rows x 12 columns]

# %% [markdown]
# The following preprocessing was necessary to model coherent topics. In fact, not only does it remove sentence elements such as punctuation or short words, but also different kinds of stopwords. On the one hand, as the dataset included descriptions in multiple languages, the stopwords from these most prevalent languages were removed; on the other, a custom list of stopwords was compiled to mainly include words relating to the field of digital art, its styles, techniques and colors. In addition, the custom stopword list also includes other words that aren’t indicative of the themes of the artworks that were spotted by going through the dataset and LDA trial results. Some of these stopwords included words that regarded digital art are “'digital”, “art”, “painting”, “artwork”, “sale”, but also “kunst” (art), “edição” (edition) “rouge” (red) “digitalmente” (digitally) and “técnica” (technique) in languages other than English. Other stop words such as “captivant” (captivating) “special” and “reveals” were included to avoid generic terms. The text that underwent preprocessing consisted of not only the textual descriptions of the artworks, but also their titles and themes (only present in the Artmajeur artworks).

# %%
# Process, normalize, and remove stop words from the descriptions
stop_words = stopwords.words('english') + stopwords.words('french') + stopwords.words('german') + stopwords.words('italian') + stopwords.words('spanish') + stopwords.words('dutch')

def filter_descriptions(descriptions):
    """
    Normalize art descriptions by removing punctuation tokens and URLs.

    Args:
        descriptions (list of str): List of description strings.

    Returns:
        list of str: List of normalized descriptions.
    """
    normalized_descriptions = []

    for description in descriptions:

        # Split into tokens
        tokens = word_tokenize(description.lower())

        normalized = []
        for token in tokens:
            if token in string.punctuation:   # Remove punctuation
              continue
            elif token in stop_words:         # Remove stop words
              continue
            elif any(str.isdigit(c) for c in token):   # Remove tokens that include numbers
              continue
            elif len(token) < 3:                       # Remove short words
              continue
            elif token.startswith(('http', 'www','(',':')):              # Remove links & complicated words
              continue
            elif token.endswith(('com',')','-','.',';',',','"',':')):    # Remove links & complicated words
              continue
            else:
                normalized.append(token)

        # Join tokens back into a string and convert to lowercase
        normalized_description = " ".join(normalized).lower()
        normalized_descriptions.append(normalized_description)

    return normalized_descriptions

# %%
df['Title + Description + Themes'] = df['Title'].astype(str) + ' ' + df['Description'].astype(str) + ' ' + df['Themes'].astype(str)
descriptions = df['Title + Description + Themes']
normalized_descriptions = filter_descriptions(descriptions)
raw_keywords = []
for desc in normalized_descriptions:
  words = list(set(desc.split())) # Convert to set to remove repetitive words
  raw_keywords.append(words)
df['Keywords'] = raw_keywords

# %% [markdown]
# Despite having mentioned LDA trial runs, the final topic modeling algorithm we used ended up being Top2Vec, as LDA’s results were not satisfying. On the contrary, Top2Vec, working with a multilingual pretrained model as a base, produced more satisfactory results and managed to find relevant and different topics in the dataset. After the topics were modeled, they were assigned back to the DataFrame rows, using a threshold score of 0.5 to ensure accuracy.

# %%
# Create the Top2Vec model
documents = df['Keywords'].apply(lambda tokens: ' '.join(tokens)).tolist()
model = Top2Vec(documents=documents, speed='learn', embedding_model='universal-sentence-encoder-multilingual')

# Get model information
topic_words, word_scores, topic_nums = model.get_topics()

for topic_num in topic_nums:
    print(f"Topic {topic_num}:")
    print("Words:", topic_words[topic_num])
    print("Scores:", word_scores[topic_num])
    print("\n")
# Out:
# 2024-06-18 21:33:02,101 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2024-06-18 21:33:02,914 - top2vec - INFO - Downloading universal-sentence-encoder-multilingual model
# INFO:top2vec:Downloading universal-sentence-encoder-multilingual model
# 2024-06-18 21:33:06,111 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2024-06-18 21:33:30,845 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2024-06-18 21:33:48,565 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2024-06-18 21:33:48,828 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics
# Topic 0:
# Words: ['evoke' 'get' 'self' 'mind' 'wonder' 'intricate' 'deep' 'look' 'feel'
#  'time' 'sense' 'see' 'street' 'represents' 'long' 'soul' 'nude' 'dance'
#  'sun' 'body' 'hand' 'water' 'moment' 'girl' 'femme' 'journey' 'face'
#  'line' 'old' 'wall' 'heart' 'used' 'back' 'female' 'earth' 'place'
#  'animal' 'living' 'sky' 'dreams' 'home' 'night' 'human' 'large'
#  'imagination' 'day' 'fantasy' 'reflection' 'decor' 'power']
# Scores: [0.7375897  0.718816   0.66986704 0.6613444  0.65603787 0.6493392
#  0.6459558  0.64400613 0.64135444 0.6404442  0.640195   0.6316486
#  0.62484896 0.62031674 0.6113976  0.6113609  0.60989904 0.6083824
#  0.6067419  0.60626704 0.60491204 0.60314584 0.59890807 0.5984658
#  0.5973082  0.59613883 0.59452474 0.5942867  0.5940006  0.5930214
#  0.5890195  0.5879015  0.5871559  0.5852127  0.5842141  0.58348584
#  0.58245546 0.5813176  0.57845485 0.5720142  0.56337184 0.56307864
#  0.55881345 0.55791366 0.5550075  0.5548378  0.55468565 0.5526205
#  0.54986733 0.5482695 ]
#
#
# Topic 1:
# Words: ['imagination' 'intricate' 'landscapes' 'landscape' 'reality' 'different'
#  'self' 'fashion' 'nude' 'time' 'represents' 'reflection' 'face' 'moment'
#  'natural' 'scene' 'evoke' 'mind' 'look' 'archival' 'emotions' 'used'
#  'back' 'decor' 'wall' 'paris' 'see' 'get' 'body' 'fantasy' 'hand' 'long'
#  'day' 'living' 'culture' 'water' 'dynamic' 'street' 'wonder' 'animal'
#  'depth' 'eyes' 'movement' 'room' 'human' 'flowers' 'women' 'connection'
#  'feel' 'line']
# Scores: [0.1771999  0.17388856 0.15740992 0.15617633 0.13702907 0.13264556
#  0.12722057 0.12545407 0.12134203 0.11873512 0.11553144 0.11494035
#  0.11434741 0.10900016 0.10701166 0.10671423 0.10575379 0.10262999
#  0.10243997 0.10041685 0.0987781  0.09853945 0.09698354 0.09663015
#  0.09402252 0.09201975 0.09126107 0.09053946 0.08908405 0.08856089
#  0.08736285 0.08684339 0.08547206 0.08538591 0.08186099 0.08183219
#  0.08176976 0.0786484  0.07800225 0.07726774 0.0745684  0.07386079
#  0.07165276 0.07141282 0.07131603 0.0695788  0.06881893 0.06770203
#  0.06669955 0.06606469]
#
#
# Topic 2:
# Words: ['imagination' 'mind' 'reflection' 'reality' 'sense' 'emotions' 'feel'
#  'fantasy' 'soul' 'intricate' 'deep' 'eyes' 'represents' 'dreams' 'see'
#  'landscape' 'depth' 'wonder' 'evoke' 'landscapes' 'self' 'moment'
#  'different' 'universe' 'heart' 'look' 'face' 'dynamic' 'symbol' 'living'
#  'body' 'human' 'energy' 'journey' 'scene' 'movement' 'time' 'natural'
#  'space' 'wall' 'sky' 'back' 'power' 'night' 'get' 'water' 'day' 'earth'
#  'dance' 'connection']
# Scores: [0.33528572 0.2626615  0.26042795 0.24054149 0.23855004 0.22370765
#  0.21679786 0.19422042 0.1883515  0.17748205 0.17568338 0.17143804
#  0.16598493 0.1652054  0.16151197 0.15837952 0.15830113 0.15820841
#  0.1543603  0.1443747  0.1437169  0.1389035  0.1382778  0.12588462
#  0.12408081 0.12395794 0.12350748 0.12105067 0.11856112 0.11385807
#  0.10534991 0.10288271 0.10220802 0.10080652 0.09975166 0.09475194
#  0.08792842 0.08590437 0.08550598 0.08467529 0.08109606 0.07235973
#  0.07052971 0.0697481  0.06658845 0.05911291 0.05566939 0.05540569
#  0.05495273 0.05378122]
#
#
# Topic 3:
# Words: ['soul' 'emotions' 'deep' 'dreams' 'heart' 'feel' 'mind' 'imagination'
#  'sense' 'evoke' 'moment' 'intricate' 'living' 'reality' 'long' 'night'
#  'fantasy' 'time' 'depth' 'wonder' 'music' 'journey' 'eyes' 'self' 'dance'
#  'earth' 'get' 'day' 'body' 'human' 'reflection' 'represents' 'sky'
#  'universe' 'energy' 'back' 'space' 'old' 'flower' 'perfect' 'face'
#  'different' 'line' 'see' 'flowers' 'symbol' 'connection' 'scene' 'power'
#  'sun']
# Scores: [0.28342187 0.24597353 0.22803351 0.22739807 0.21467766 0.21318461
#  0.20631298 0.20081186 0.19042645 0.18807119 0.1696471  0.16642942
#  0.1642839  0.16348457 0.16319704 0.15445718 0.14727417 0.1459203
#  0.14446293 0.14283162 0.14147888 0.13956974 0.13785431 0.13778403
#  0.13681474 0.13449122 0.12688676 0.12515056 0.1246938  0.1181415
#  0.1164863  0.11635108 0.11206285 0.10954228 0.10938649 0.10936193
#  0.10680837 0.10447223 0.09945472 0.09920067 0.09806564 0.09663413
#  0.09326914 0.09158231 0.09055728 0.08995053 0.08911879 0.08741065
#  0.0870207  0.08479784]
#
#
# Topic 4:
# Words: ['fantasy' 'imagination' 'sense' 'evoke' 'intricate' 'reality' 'mind'
#  'female' 'femme' 'wonder' 'women' 'emotions' 'power' 'girl' 'feel'
#  'moment' 'eyes' 'dreams' 'soul' 'deep' 'flower' 'night' 'self' 'universe'
#  'scene' 'dynamic' 'natural' 'represents' 'see' 'dance' 'depth'
#  'reflection' 'flowers' 'time' 'get' 'perfect' 'different' 'energy' 'look'
#  'connection' 'heart' 'landscape' 'body' 'movement' 'landscapes' 'symbol'
#  'room' 'culture' 'face' 'journey']
# Scores: [0.24519044 0.22192645 0.16578719 0.16507924 0.1582344  0.15659966
#  0.15049568 0.14544338 0.14047527 0.13657697 0.13510995 0.13186301
#  0.12816812 0.12733032 0.12331538 0.11865114 0.1149764  0.11468875
#  0.11373512 0.11223742 0.10938936 0.10517491 0.10492529 0.10274473
#  0.10229906 0.10149422 0.09690958 0.09601212 0.08997107 0.08923396
#  0.08782056 0.08308235 0.07975773 0.07858221 0.07738136 0.07664998
#  0.07286942 0.0720071  0.07141646 0.07007783 0.06781533 0.06648149
#  0.0647455  0.06217355 0.05854394 0.05724246 0.05692373 0.05458977
#  0.0537088  0.05075201]
#
#
# Topic 5:
# Words: ['landscape' 'imagination' 'landscapes' 'face' 'fashion' 'intricate'
#  'decor' 'scene' 'symbol' 'fantasy' 'reflection' 'line' 'body'
#  'represents' 'eyes' 'look' 'evoke' 'dynamic' 'dance' 'nude' 'wall'
#  'reality' 'emotions' 'different' 'movement' 'music' 'journey' 'mind'
#  'self' 'animal' 'hand' 'heart' 'flowers' 'dreams' 'time' 'sky' 'girl'
#  'sun' 'archival' 'soul' 'human' 'living' 'culture' 'natural' 'old'
#  'flower' 'see' 'sense' 'space' 'universe']
# Scores: [0.5397582  0.5390205  0.5196769  0.5063788  0.48131797 0.48063183
#  0.4776414  0.47750723 0.47254285 0.46820652 0.46478447 0.43938446
#  0.43532848 0.43380564 0.42888993 0.4227548  0.42251348 0.41348568
#  0.41251105 0.4097908  0.40933597 0.40470374 0.4042165  0.4036427
#  0.4005103  0.39640272 0.39390558 0.3933918  0.39129505 0.38843277
#  0.37510884 0.3673884  0.35828364 0.35731366 0.35403842 0.35224587
#  0.3513966  0.3504515  0.34932435 0.345745   0.34232128 0.34214273
#  0.33817717 0.33809215 0.3376497  0.33587226 0.3338793  0.32955915
#  0.32636154 0.32096225]
#
#
# Topic 6:
# Words: ['imagination' 'emotions' 'mind' 'soul' 'sense' 'feel' 'reflection' 'deep'
#  'eyes' 'dreams' 'reality' 'energy' 'evoke' 'intricate' 'fantasy' 'depth'
#  'universe' 'dynamic' 'moment' 'wonder' 'power' 'heart' 'self' 'movement'
#  'represents' 'journey' 'dance' 'human' 'night' 'symbol' 'body' 'culture'
#  'space' 'living' 'flower' 'music' 'see' 'connection' 'landscapes' 'time'
#  'scene' 'landscape' 'different' 'water' 'room' 'wall' 'decor' 'look'
#  'flowers' 'day']
# Scores: [0.23158017 0.23035252 0.19387707 0.17118882 0.16856226 0.15669554
#  0.15346795 0.13403395 0.13227648 0.13082094 0.12912846 0.12832183
#  0.12081267 0.11586431 0.11550215 0.11325194 0.10821477 0.10092817
#  0.09180406 0.09165913 0.08981737 0.0895614  0.08951622 0.08557728
#  0.08545943 0.0828947  0.082848   0.08020376 0.07828575 0.07533211
#  0.07139795 0.06728366 0.06688674 0.06429414 0.06421831 0.06294795
#  0.0628614  0.06062337 0.05861395 0.05856162 0.05739052 0.0532243
#  0.05262838 0.04813431 0.043862   0.0436815  0.04327931 0.04056131
#  0.03598332 0.03400919]
#
#
# Topic 7:
# Words: ['wall' 'line' 'reflection' 'intricate' 'room' 'different' 'represents'
#  'decor' 'imagination' 'moment' 'time' 'mind' 'reality' 'space' 'see'
#  'landscape' 'face' 'back' 'long' 'paris' 'archival' 'dynamic' 'perfect'
#  'feel' 'emotions' 'connection' 'landscapes' 'day' 'wonder' 'self' 'get'
#  'look' 'scene' 'depth' 'sense' 'city' 'evoke' 'symbol' 'night' 'street'
#  'universe' 'large' 'nude' 'used' 'free' 'natural' 'sky' 'sun' 'women'
#  'power']
# Scores: [0.11777611 0.11745483 0.10510315 0.10187431 0.09175439 0.08867718
#  0.08748102 0.08745742 0.08346862 0.08340136 0.07780741 0.07294761
#  0.07023411 0.06961034 0.06904392 0.06708568 0.06609879 0.06522176
#  0.0651827  0.06473453 0.06415246 0.06046118 0.05869368 0.05798728
#  0.05782784 0.05734508 0.05651857 0.0550654  0.05287395 0.05058133
#  0.04979309 0.04972525 0.04966249 0.04759168 0.04647018 0.04515161
#  0.03915245 0.03915088 0.03883788 0.03316483 0.0321449  0.02953357
#  0.02873095 0.02798958 0.02424448 0.02386471 0.02112335 0.02092023
#  0.0183547  0.01646416]
#
#
# Topic 8:
# Words: ['sky' 'evoke' 'soul' 'fantasy' 'symbol' 'girl' 'sun' 'night' 'face'
#  'universe' 'american' 'reflection' 'represents' 'earth' 'archival'
#  'dreams' 'line' 'paris' 'imagination' 'flower' 'eyes' 'nude' 'flowers'
#  'human' 'body' 'journey' 'deep' 'female' 'heart' 'old' 'natural' 'wonder'
#  'self' 'femme' 'long' 'dance' 'home' 'wall' 'street' 'scene' 'moment'
#  'day' 'free' 'time' 'intricate' 'landscape' 'different' 'animal'
#  'perfect' 'large']
# Scores: [0.38520524 0.3710061  0.3708017  0.32468453 0.29678068 0.29011554
#  0.28608665 0.28472003 0.27785552 0.27289313 0.26942232 0.26751256
#  0.26351857 0.26288885 0.26194656 0.26185846 0.25642914 0.25174838
#  0.24966112 0.24928412 0.2471602  0.24557301 0.24363281 0.24119464
#  0.23878713 0.23841184 0.23656341 0.23350057 0.23275033 0.2323178
#  0.22871372 0.2275818  0.2250477  0.22382307 0.22283575 0.2217789
#  0.2205262  0.2178578  0.21022141 0.20664832 0.19400196 0.19186676
#  0.18785697 0.1875685  0.18499823 0.1818664  0.18035188 0.17928123
#  0.17907229 0.1715382 ]
#
#
# Topic 9:
# Words: ['landscape' 'landscapes' 'water' 'depth' 'natural' 'mind' 'sky' 'sense'
#  'deep' 'earth' 'sun' 'imagination' 'reality' 'fantasy' 'reflection'
#  'feel' 'different' 'line' 'self' 'moment' 'emotions' 'long' 'intricate'
#  'wonder' 'scene' 'perfect' 'see' 'represents' 'day' 'time' 'evoke'
#  'culture' 'dreams' 'flowers' 'space' 'face' 'journey' 'free' 'living'
#  'get' 'room' 'flower' 'universe' 'heart' 'decor' 'place' 'old' 'night'
#  'connection' 'archival']
# Scores: [0.29766026 0.2797282  0.17380403 0.1683383  0.14809164 0.14098379
#  0.13814084 0.13234663 0.13231276 0.12603131 0.12523496 0.12278019
#  0.11230969 0.10774574 0.10553062 0.10505147 0.10051706 0.09945503
#  0.09909371 0.09520765 0.09172699 0.09110934 0.0908707  0.08725578
#  0.08670421 0.08298989 0.08280394 0.08131166 0.08051194 0.07537332
#  0.07499851 0.06755798 0.06635845 0.06628916 0.06566347 0.06557733
#  0.06238516 0.06158736 0.06053858 0.05813381 0.05751652 0.05715822
#  0.05636828 0.05566391 0.05345816 0.05174411 0.05170514 0.05091984
#  0.04711116 0.04688337]
#
#
# Topic 10:
# Words: ['flower' 'flowers' 'emotions' 'landscape' 'heart' 'landscapes'
#  'imagination' 'mind' 'sense' 'feel' 'reality' 'wonder' 'intricate'
#  'moment' 'perfect' 'fantasy' 'free' 'evoke' 'different' 'self' 'natural'
#  'girl' 'soul' 'reflection' 'line' 'day' 'sky' 'represents' 'dreams' 'see'
#  'water' 'symbol' 'get' 'space' 'dance' 'femme' 'female' 'dynamic' 'decor'
#  'women' 'power' 'culture' 'connection' 'deep' 'sun' 'time' 'scene' 'eyes'
#  'depth' 'living']
# Scores: [0.3891195  0.38703346 0.15414727 0.1527757  0.13796031 0.13762881
#  0.13673812 0.1304349  0.12777783 0.12462971 0.10589248 0.0931498
#  0.08854888 0.08849486 0.0881608  0.08690725 0.08358519 0.0814772
#  0.08131897 0.07764395 0.0752045  0.0731808  0.07139797 0.06745391
#  0.06728978 0.06713795 0.06641322 0.06606645 0.0655599  0.06434862
#  0.06345096 0.06251289 0.0606907  0.05916972 0.05793287 0.05790101
#  0.05762418 0.05698283 0.05620721 0.05496463 0.05412506 0.05401772
#  0.05311064 0.05150096 0.04993405 0.04954366 0.04765162 0.04724356
#  0.04341339 0.04307074]
#
#
# Topic 11:
# Words: ['get' 'see' 'time' 'feel' 'moment' 'wonder' 'represents' 'look' 'sense'
#  'street' 'mind' 'hand' 'self' 'water' 'back' 'used' 'power' 'day' 'body'
#  'femme' 'deep' 'evoke' 'place' 'animal' 'room' 'old' 'living' 'women'
#  'sun' 'long' 'different' 'connection' 'wall' 'line' 'night' 'large'
#  'earth' 'intricate' 'female' 'perfect' 'energy' 'decor' 'soul' 'culture'
#  'heart' 'nude' 'depth' 'young' 'human' 'sky']
# Scores: [0.710891   0.66699743 0.5509598  0.54713917 0.5426786  0.54152626
#  0.5343854  0.53004116 0.5287914  0.52708185 0.5253228  0.50996506
#  0.5083406  0.50786847 0.5053838  0.50038415 0.49848214 0.48762578
#  0.48019212 0.47359872 0.4731966  0.47064412 0.46639693 0.46112615
#  0.45855883 0.45669872 0.45046777 0.44870645 0.4471114  0.43788207
#  0.43485504 0.433141   0.43264633 0.42928785 0.42593524 0.42496037
#  0.42461544 0.41633222 0.41509473 0.41222292 0.41118836 0.40968376
#  0.407476   0.40674728 0.4064789  0.40391627 0.39902866 0.39892298
#  0.39501393 0.38865194]
#
#
# Topic 12:
# Words: ['night' 'sky' 'sun' 'fantasy' 'dreams' 'nude' 'earth' 'universe' 'day'
#  'dance' 'space' 'soul' 'imagination' 'deep' 'landscape' 'journey' 'evoke'
#  'home' 'reflection' 'long' 'time' 'flower' 'street' 'eyes' 'landscapes'
#  'moment' 'girl' 'heart' 'face' 'flowers' 'wall' 'symbol' 'scene' 'line'
#  'paris' 'city' 'natural' 'water' 'music' 'depth' 'mind' 'animal'
#  'american' 'free' 'human' 'wonder' 'intricate' 'reality' 'large' 'living']
# Scores: [0.60127807 0.5818339  0.48446918 0.4402098  0.41783732 0.41588837
#  0.40023816 0.38409883 0.37020046 0.3692452  0.35988095 0.35884666
#  0.35704416 0.3478204  0.34713936 0.3436144  0.33863032 0.33702177
#  0.32938233 0.324371   0.32327008 0.32001993 0.31990796 0.31820723
#  0.315835   0.31052905 0.30949184 0.30752158 0.3067444  0.30603725
#  0.30340376 0.29628247 0.2932837  0.29134998 0.2896921  0.28782952
#  0.2840349  0.28390557 0.2707805  0.26934126 0.26837772 0.2683397
#  0.26810497 0.26650977 0.2652482  0.26448452 0.26317823 0.2588224
#  0.25718063 0.2571514 ]
#
#
# Topic 13:
# Words: ['femme' 'female' 'women' 'nude' 'girl' 'fantasy' 'body' 'soul' 'natural'
#  'imagination' 'fashion' 'self' 'eyes' 'symbol' 'face' 'heart' 'dance'
#  'reflection' 'living' 'reality' 'sense' 'intricate' 'dreams' 'long'
#  'culture' 'human' 'scene' 'decor' 'emotions' 'evoke' 'flowers' 'flower'
#  'mind' 'feel' 'represents' 'landscape' 'dynamic' 'deep' 'perfect' 'home'
#  'wonder' 'free' 'wall' 'landscapes' 'moment' 'universe' 'different'
#  'night' 'movement' 'old']
# Scores: [0.3995172  0.3874787  0.38344967 0.34854713 0.34234175 0.25000942
#  0.24453749 0.19790523 0.18332586 0.18057449 0.17703113 0.16958682
#  0.16282919 0.15844381 0.1574421  0.15590754 0.15441877 0.1511287
#  0.1509572  0.14147833 0.13827887 0.13826665 0.13518035 0.13281989
#  0.1327008  0.13215105 0.13158819 0.12875254 0.11718661 0.11646274
#  0.11555656 0.11493175 0.11356796 0.11086738 0.10879758 0.10735375
#  0.10576219 0.10173136 0.0977761  0.09411387 0.09224519 0.08949934
#  0.08867848 0.0842972  0.08225881 0.07547616 0.07211329 0.07176912
#  0.06622565 0.06583023]
#
#
# Topic 14:
# Words: ['imagination' 'intricate' 'hand' 'symbol' 'heart' 'represents'
#  'landscape' 'large' 'self' 'mind' 'water' 'emotions' 'long' 'fantasy'
#  'decor' 'line' 'room' 'feel' 'face' 'landscapes' 'different' 'time' 'old'
#  'nude' 'day' 'depth' 'wall' 'reality' 'girl' 'flowers' 'animal' 'space'
#  'human' 'body' 'eyes' 'culture' 'flower' 'sense' 'wonder' 'perfect'
#  'deep' 'young' 'get' 'sun' 'female' 'see' 'femme' 'paris' 'women' 'look']
# Scores: [0.15560855 0.12818979 0.12398755 0.11145136 0.10999863 0.10283589
#  0.09459706 0.09371845 0.09326656 0.09165736 0.08961625 0.08612797
#  0.08055684 0.07999146 0.07906181 0.07704156 0.07171331 0.06863558
#  0.06855141 0.0663303  0.06299497 0.06228014 0.05839244 0.05757336
#  0.05529045 0.05435355 0.05369296 0.05052526 0.05049597 0.05002232
#  0.04578292 0.04378548 0.04366164 0.04174098 0.04006897 0.03899656
#  0.03879599 0.03831432 0.03799538 0.03504423 0.03447694 0.03367857
#  0.03238024 0.03172169 0.03154593 0.0313962  0.0281914  0.02735446
#  0.02617048 0.02598597]
#
#
# Topic 15:
# Words: ['human' 'fantasy' 'imagination' 'reality' 'soul' 'universe' 'self'
#  'intricate' 'emotions' 'girl' 'sky' 'face' 'dance' 'wonder' 'evoke'
#  'dreams' 'scene' 'perfect' 'deep' 'earth' 'sense' 'natural' 'living'
#  'long' 'american' 'archival' 'mind' 'animal' 'journey' 'dynamic' 'free'
#  'symbol' 'eyes' 'nude' 'old' 'music' 'time' 'female' 'culture' 'femme'
#  'body' 'represents' 'movement' 'women' 'feel' 'reflection' 'landscape'
#  'fashion' 'home' 'space']
# Scores: [0.2910431  0.27152848 0.24779135 0.2128033  0.1982649  0.19541338
#  0.19160154 0.19097507 0.18081878 0.17807963 0.17703941 0.16945109
#  0.16719735 0.16078153 0.15310118 0.14686054 0.14675122 0.14574249
#  0.14121547 0.14079082 0.13387614 0.13257304 0.13047655 0.12757364
#  0.12715887 0.12651525 0.12438834 0.12393162 0.12369438 0.1229623
#  0.12145905 0.11954598 0.11848953 0.11635861 0.11325072 0.11312243
#  0.10712118 0.10453582 0.10435536 0.10418104 0.10045607 0.09846833
#  0.09829524 0.09396656 0.09074908 0.09064759 0.08603199 0.08566174
#  0.08539747 0.08535695]
#
#
# Topic 16:
# Words: ['nude' 'women' 'femme' 'female' 'imagination' 'sense' 'fantasy' 'girl'
#  'feel' 'body' 'mind' 'emotions' 'natural' 'dance' 'self' 'reality'
#  'moment' 'scene' 'different' 'soul' 'see' 'evoke' 'wonder' 'fashion'
#  'power' 'reflection' 'movement' 'represents' 'dynamic' 'night' 'eyes'
#  'deep' 'culture' 'intricate' 'room' 'dreams' 'perfect' 'get' 'look'
#  'flower' 'living' 'time' 'landscape' 'energy' 'place' 'landscapes' 'home'
#  'decor' 'depth' 'face']
# Scores: [0.3444361  0.21286468 0.20691976 0.19986272 0.19498177 0.18227822
#  0.18098396 0.18007296 0.17989951 0.17596583 0.15831783 0.14719841
#  0.14562228 0.14445186 0.1442938  0.14198744 0.13148259 0.12441041
#  0.11796443 0.11505989 0.11178599 0.10842474 0.10830018 0.10732578
#  0.1042435  0.10375788 0.10163984 0.10098399 0.09918791 0.09786985
#  0.09718582 0.09603428 0.09569652 0.09530075 0.09327524 0.09290716
#  0.09205717 0.09050228 0.08936752 0.08334672 0.07935361 0.0752167
#  0.07398666 0.07207121 0.07089779 0.06794329 0.06567136 0.06531209
#  0.06332858 0.06311508]
#
#
# Topic 17:
# Words: ['music' 'evoke' 'paris' 'dance' 'fantasy' 'soul' 'journey' 'sky'
#  'intricate' 'animal' 'girl' 'deep' 'scene' 'represents' 'wonder' 'dreams'
#  'face' 'american' 'archival' 'universe' 'night' 'earth' 'heart' 'eyes'
#  'imagination' 'symbol' 'human' 'natural' 'landscape' 'female' 'sense'
#  'long' 'street' 'self' 'old' 'home' 'flower' 'fashion' 'nude' 'emotions'
#  'feel' 'sun' 'perfect' 'mind' 'landscapes' 'femme' 'city' 'reality'
#  'flowers' 'day']
# Scores: [0.26730508 0.24825606 0.24596615 0.23893817 0.23202625 0.22406858
#  0.20815048 0.20370841 0.20308584 0.19916376 0.19660167 0.1957837
#  0.19431579 0.18076052 0.17620964 0.17480922 0.16618884 0.16578616
#  0.16433391 0.15602912 0.15386975 0.14757696 0.14718053 0.14483199
#  0.14418781 0.13752782 0.13603947 0.13504569 0.13431272 0.12978885
#  0.12888913 0.12756409 0.12733248 0.12631007 0.12270725 0.11982831
#  0.11950991 0.11887581 0.11813951 0.11768727 0.11487935 0.11395261
#  0.11287998 0.11100977 0.11012878 0.10853834 0.10643069 0.10496492
#  0.10478794 0.1007576 ]
#
#
# Topic 18:
# Words: ['girl' 'femme' 'female' 'women' 'eyes' 'young' 'heart' 'human' 'face'
#  'soul' 'flower' 'flowers' 'old' 'nude' 'fantasy' 'long' 'body' 'dance'
#  'look' 'wonder' 'american' 'sun' 'evoke' 'living' 'hand' 'mind' 'journey'
#  'culture' 'animal' 'home' 'dreams' 'night' 'symbol' 'self' 'music' 'wall'
#  'represents' 'natural' 'earth' 'imagination' 'time' 'sense' 'fashion'
#  'day' 'feel' 'intricate' 'emotions' 'landscape' 'deep' 'scene']
# Scores: [0.80326664 0.7641864  0.7464337  0.7278626  0.47092944 0.46209532
#  0.45578533 0.44749716 0.44106132 0.43899295 0.43754697 0.4337418
#  0.42899722 0.4259351  0.41914666 0.41273016 0.40936837 0.4036339
#  0.40345472 0.40294027 0.40106443 0.39146146 0.39133054 0.38973358
#  0.3893335  0.38859022 0.38401645 0.38198075 0.37565613 0.3753486
#  0.37508488 0.36943865 0.36918968 0.3689282  0.36694348 0.36511365
#  0.36492997 0.36271274 0.35843527 0.35808116 0.35761994 0.3555456
#  0.35452884 0.3520919  0.35197806 0.3483641  0.34543288 0.3386509
#  0.33695394 0.33663845]
#
#
# Topic 19:
# Words: ['sun' 'day' 'night' 'sky' 'journey' 'earth' 'home' 'time' 'fantasy'
#  'reflection' 'landscape' 'dreams' 'moment' 'flower' 'flowers'
#  'landscapes' 'energy' 'living' 'nude' 'old' 'universe' 'soul' 'natural'
#  'girl' 'long' 'evoke' 'face' 'imagination' 'feel' 'back' 'fashion'
#  'dance' 'mind' 'young' 'street' 'heart' 'eyes' 'water' 'space' 'femme'
#  'represents' 'reality' 'get' 'body' 'emotions' 'self' 'wonder' 'look'
#  'paris' 'sense']
# Scores: [0.7490671  0.5837277  0.5051213  0.49650502 0.44268504 0.43284792
#  0.4301733  0.41888183 0.40561813 0.40315145 0.40219727 0.3964644
#  0.3928535  0.39266884 0.39042598 0.38548177 0.37776506 0.37714112
#  0.37474823 0.37288806 0.36922383 0.3608961  0.3579028  0.35616958
#  0.35548067 0.35374457 0.35133618 0.3488292  0.3469115  0.3460188
#  0.34305835 0.3416112  0.34155512 0.33639243 0.33575094 0.33472538
#  0.33404508 0.33048362 0.32065076 0.31878793 0.31866488 0.31635582
#  0.31617254 0.31603944 0.31277588 0.31116742 0.31108093 0.30770913
#  0.30392766 0.29997897]
#
#
# Topic 20:
# Words: ['universe' 'space' 'earth' 'sky' 'imagination' 'fantasy' 'reality' 'sun'
#  'intricate' 'landscape' 'landscapes' 'dreams' 'deep' 'mind' 'soul'
#  'living' 'depth' 'room' 'sense' 'reflection' 'self' 'night' 'wonder'
#  'energy' 'perfect' 'feel' 'large' 'journey' 'human' 'body' 'emotions'
#  'natural' 'flowers' 'flower' 'different' 'place' 'decor' 'evoke' 'moment'
#  'scene' 'free' 'represents' 'long' 'dance' 'see' 'symbol' 'time'
#  'culture' 'eyes' 'movement']
# Scores: [0.44461048 0.37105417 0.30716446 0.28736785 0.2418482  0.2076368
#  0.19049141 0.17996007 0.16723078 0.16073495 0.1578164  0.15566479
#  0.15462059 0.14867464 0.13643104 0.12807044 0.12382947 0.11347526
#  0.10760376 0.10588575 0.10351977 0.1019308  0.09814401 0.09412284
#  0.08983146 0.08933203 0.08928175 0.08789316 0.08762284 0.08679763
#  0.08081989 0.07961346 0.07878791 0.07826152 0.07807893 0.0746908
#  0.06742299 0.06719822 0.06713846 0.06638829 0.06511452 0.06412482
#  0.06306124 0.06111266 0.06066496 0.05893325 0.05890204 0.05619871
#  0.05537345 0.05100537]
#
#
# Topic 21:
# Words: ['landscape' 'landscapes' 'sky' 'fantasy' 'scene' 'natural' 'imagination'
#  'flowers' 'earth' 'flower' 'eyes' 'sun' 'face' 'dreams' 'reflection'
#  'depth' 'journey' 'deep' 'emotions' 'decor' 'symbol' 'reality' 'culture'
#  'mind' 'different' 'water' 'represents' 'soul' 'intricate' 'space'
#  'living' 'heart' 'animal' 'sense' 'music' 'line' 'dynamic' 'place' 'city'
#  'feel' 'wall' 'moment' 'look' 'night' 'self' 'evoke' 'archival' 'street'
#  'nude' 'universe']
# Scores: [0.6829848  0.6658697  0.32585996 0.32041523 0.31544256 0.2947765
#  0.28717816 0.26570883 0.24439055 0.23374295 0.22012167 0.21311411
#  0.21166466 0.21044618 0.20228387 0.20105241 0.19188744 0.19185787
#  0.18891859 0.17997643 0.17778912 0.17760451 0.17669792 0.16954988
#  0.16772707 0.16734967 0.15282142 0.15236582 0.15113261 0.15042388
#  0.14949995 0.14885724 0.14878038 0.14839216 0.14766756 0.14658552
#  0.1460048  0.1389813  0.13889441 0.13869353 0.13826376 0.13615948
#  0.1285035  0.12755139 0.1265671  0.124539   0.12435192 0.12372325
#  0.12367102 0.12327394]
#
#
# Topic 22:
# Words: ['animal' 'sense' 'intricate' 'human' 'emotions' 'feel' 'mind'
#  'imagination' 'moment' 'reality' 'self' 'natural' 'fantasy' 'perfect'
#  'eyes' 'time' 'wonder' 'long' 'evoke' 'get' 'represents' 'different'
#  'face' 'deep' 'living' 'see' 'dreams' 'connection' 'scene' 'soul' 'dance'
#  'heart' 'movement' 'power' 'day' 'body' 'old' 'landscape' 'look'
#  'dynamic' 'landscapes' 'girl' 'water' 'flower' 'female' 'earth' 'night'
#  'place' 'energy' 'symbol']
# Scores: [0.3446963  0.18545194 0.18539199 0.1799199  0.17590663 0.16888341
#  0.16794047 0.16667506 0.1428764  0.14267004 0.1400019  0.13602471
#  0.13285923 0.1262843  0.12620157 0.12337443 0.12222619 0.12191267
#  0.12146087 0.11918195 0.1100046  0.10905372 0.10616361 0.10535249
#  0.10295366 0.10121569 0.10085205 0.10062758 0.10010313 0.09730824
#  0.09615755 0.09503606 0.09484141 0.09451714 0.09223485 0.0904263
#  0.08950354 0.08797193 0.08650967 0.0849286  0.08277549 0.0775547
#  0.07537154 0.07381416 0.07336371 0.07192839 0.07153711 0.07029843
#  0.06791455 0.06717432]
#
#
# Topic 23:
# Words: ['archival' 'paris' 'american' 'long' 'soul' 'free' 'girl' 'wonder' 'home'
#  'young' 'deep' 'old' 'journey' 'heart' 'night' 'evoke' 'fantasy' 'nude'
#  'earth' 'sky' 'dance' 'perfect' 'street' 'universe' 'city' 'dreams'
#  'human' 'large' 'natural' 'wall' 'intricate' 'femme' 'depth' 'reflection'
#  'represents' 'fashion' 'different' 'cotton' 'dynamic' 'time' 'symbol'
#  'back' 'eyes' 'day' 'flower' 'imagination' 'music' 'moment' 'self'
#  'female']
# Scores: [0.33454394 0.3005073  0.29816008 0.20295244 0.19606844 0.18082458
#  0.18077824 0.1752644  0.17525208 0.17343941 0.17338403 0.1699684
#  0.16430923 0.16415064 0.16283096 0.15821266 0.15792805 0.15500352
#  0.14692354 0.14523914 0.14137805 0.13767108 0.13746865 0.13462794
#  0.13455583 0.13423157 0.12853518 0.12669386 0.12602605 0.1227427
#  0.11761128 0.11404823 0.1111792  0.10916723 0.10880776 0.10826868
#  0.10792919 0.10638408 0.10117302 0.10113004 0.09834015 0.0970916
#  0.09595909 0.094988   0.09188703 0.09046171 0.08817376 0.08708912
#  0.08507984 0.08323484]
#
#
# Topic 24:
# Words: ['water' 'depth' 'landscape' 'imagination' 'landscapes' 'deep' 'reality'
#  'reflection' 'fantasy' 'sky' 'mind' 'different' 'earth' 'universe'
#  'sense' 'sun' 'animal' 'emotions' 'intricate' 'moment' 'natural' 'evoke'
#  'dreams' 'represents' 'space' 'self' 'line' 'living' 'see' 'time' 'scene'
#  'feel' 'day' 'wonder' 'dynamic' 'eyes' 'room' 'decor' 'power' 'look'
#  'perfect' 'city' 'get' 'night' 'flowers' 'connection' 'soul' 'symbol'
#  'energy' 'human']
# Scores: [0.22862795 0.22595268 0.20166507 0.20139289 0.19630264 0.18855691
#  0.15072486 0.14927699 0.14633448 0.14368784 0.1261209  0.12348523
#  0.12205088 0.1163027  0.11334386 0.11298046 0.11272235 0.10817128
#  0.1058338  0.10154594 0.10056645 0.09678116 0.09661207 0.09572224
#  0.09251074 0.09080551 0.08953243 0.08801624 0.08782536 0.0837483
#  0.08292784 0.08223435 0.07908106 0.07833843 0.0763384  0.06614886
#  0.06553611 0.06501047 0.06282774 0.05891649 0.05742414 0.05491802
#  0.05385586 0.05316458 0.0529732  0.05051276 0.04973225 0.04968537
#  0.04898334 0.0482679 ]
#
#
# Topic 25:
# Words: ['flowers' 'flower' 'landscape' 'symbol' 'landscapes' 'girl' 'heart'
#  'decor' 'dreams' 'sun' 'dance' 'cotton' 'eyes' 'female' 'nude' 'femme'
#  'sky' 'water' 'emotions' 'represents' 'imagination' 'fantasy' 'night'
#  'soul' 'fashion' 'face' 'culture' 'reflection' 'home' 'natural' 'day'
#  'women' 'body' 'hand' 'mind' 'earth' 'street' 'universe' 'line' 'wall'
#  'animal' 'scene' 'evoke' 'look' 'human' 'paris' 'different' 'journey'
#  'long' 'intricate']
# Scores: [0.85494745 0.8490215  0.36468995 0.36188498 0.35259432 0.31230557
#  0.30104226 0.2990387  0.2957859  0.29531407 0.28949177 0.2859769
#  0.285538   0.2757488  0.27529454 0.27450037 0.2735707  0.27343547
#  0.26084453 0.25968006 0.25363815 0.2532069  0.25058743 0.24983114
#  0.24940623 0.24455872 0.24094602 0.24010557 0.239828   0.23878714
#  0.23415253 0.23350042 0.22548077 0.22356744 0.22243941 0.22106749
#  0.22018775 0.22014067 0.21800032 0.2165677  0.2158095  0.21521275
#  0.21503694 0.21434918 0.21150531 0.2099896  0.20949754 0.20841248
#  0.20419683 0.20322624]
#
#
# Topic 26:
# Words: ['sky' 'earth' 'universe' 'space' 'sun' 'landscape' 'landscapes' 'soul'
#  'fantasy' 'imagination' 'symbol' 'night' 'reflection' 'dreams' 'natural'
#  'human' 'reality' 'deep' 'heart' 'nude' 'living' 'body' 'flowers'
#  'flower' 'face' 'intricate' 'eyes' 'self' 'depth' 'free' 'represents'
#  'journey' 'dance' 'mind' 'evoke' 'sense' 'home' 'long' 'old' 'animal'
#  'scene' 'girl' 'room' 'large' 'decor' 'wall' 'american' 'female' 'water'
#  'wonder']
# Scores: [0.41025198 0.35205775 0.3430565  0.34099093 0.32744676 0.2373448
#  0.21081692 0.20519203 0.1822499  0.17973793 0.17706448 0.167853
#  0.16601487 0.16594326 0.14973697 0.14563113 0.13506526 0.13281292
#  0.12551317 0.12501886 0.11387181 0.11333638 0.11203627 0.11032531
#  0.10692482 0.1059978  0.10498092 0.10189152 0.10160352 0.09931672
#  0.09503508 0.09375734 0.09351433 0.09057264 0.0857714  0.08109502
#  0.07867976 0.07397301 0.07380119 0.07050762 0.07033473 0.06955591
#  0.06505126 0.06504555 0.06242707 0.06063909 0.05945838 0.05927145
#  0.05891095 0.05886653]
#
#
# Topic 27:
# Words: ['music' 'dance' 'old' 'long' 'soul' 'represents' 'wonder' 'scene' 'sky'
#  'american' 'night' 'evoke' 'intricate' 'living' 'fashion' 'fantasy'
#  'time' 'get' 'moment' 'reality' 'deep' 'universe' 'back' 'movement' 'day'
#  'free' 'mind' 'archival' 'natural' 'perfect' 'culture' 'paris' 'street'
#  'large' 'feel' 'human' 'sense' 'self' 'young' 'body' 'dreams' 'room'
#  'imagination' 'femme' 'reflection' 'heart' 'used' 'dynamic' 'earth'
#  'emotions']
# Scores: [0.24122122 0.16358101 0.1488642  0.11390819 0.10992303 0.10572813
#  0.10535592 0.10193305 0.09908596 0.09896003 0.09743729 0.09543274
#  0.09500991 0.08995929 0.08961459 0.08757202 0.08742081 0.08520368
#  0.08459494 0.08443397 0.0821253  0.08197858 0.08106321 0.07802556
#  0.07704885 0.07531899 0.07530023 0.07463626 0.07190284 0.07082784
#  0.06936222 0.06811195 0.06700485 0.06688093 0.06563815 0.06393438
#  0.06044557 0.06034651 0.05982948 0.05806997 0.05758204 0.05750546
#  0.0554346  0.04980079 0.04878781 0.04800016 0.04710719 0.04702359
#  0.04644873 0.04615933]
#
#
# Topic 28:
# Words: ['water' 'sun' 'deep' 'landscape' 'landscapes' 'depth' 'journey' 'sky'
#  'evoke' 'nude' 'home' 'earth' 'body' 'dance' 'line' 'soul' 'fantasy'
#  'place' 'reflection' 'dreams' 'decor' 'wall' 'face' 'music' 'mind'
#  'street' 'girl' 'animal' 'living' 'long' 'heart' 'flowers' 'female'
#  'natural' 'city' 'femme' 'look' 'symbol' 'intricate' 'universe' 'eyes'
#  'space' 'flower' 'get' 'night' 'old' 'time' 'room' 'represents'
#  'american']
# Scores: [0.57908404 0.49493122 0.46958268 0.45441777 0.4494628  0.44157052
#  0.43633938 0.42990285 0.41234165 0.41110379 0.4076035  0.40698916
#  0.4053911  0.39950708 0.395844   0.3942778  0.3911043  0.3893832
#  0.38913548 0.38893974 0.38270873 0.38083145 0.38063464 0.38005897
#  0.37534654 0.37444058 0.3738389  0.37355164 0.36764836 0.36724675
#  0.36636972 0.36605483 0.3653055  0.36482716 0.3631057  0.35954094
#  0.35876384 0.35811037 0.35209084 0.3519311  0.3512246  0.35064897
#  0.34816402 0.34679157 0.34371024 0.34204787 0.3395058  0.33909988
#  0.33831275 0.3340432 ]
#
#
# Topic 29:
# Words: ['animal' 'sky' 'evoke' 'human' 'landscape' 'heart' 'flowers' 'landscapes'
#  'face' 'dance' 'girl' 'sun' 'intricate' 'flower' 'paris' 'eyes' 'fantasy'
#  'street' 'symbol' 'young' 'earth' 'natural' 'represents' 'journey' 'deep'
#  'reflection' 'female' 'night' 'hand' 'archival' 'imagination' 'dreams'
#  'nude' 'soul' 'look' 'wonder' 'old' 'wall' 'decor' 'body' 'water' 'long'
#  'cotton' 'mind' 'american' 'music' 'day' 'fashion' 'scene' 'time']
# Scores: [0.48695493 0.3740315  0.33263695 0.3157519  0.31483722 0.313282
#  0.31022245 0.30356187 0.30171317 0.30024332 0.29386607 0.29307738
#  0.2894455  0.28900862 0.2792221  0.27571324 0.26905024 0.26824576
#  0.263119   0.26211974 0.25888088 0.25842217 0.25556678 0.25488922
#  0.25222406 0.24943075 0.24863027 0.245053   0.24477467 0.2446382
#  0.2408446  0.24051735 0.23930112 0.23706584 0.2359524  0.23497108
#  0.23246321 0.23210424 0.22781445 0.22720845 0.22468911 0.2202889
#  0.21949145 0.21790895 0.21748677 0.21393454 0.21291098 0.21038997
#  0.21007015 0.20918448]
#
#
# Topic 30:
# Words: ['city' 'street' 'paris' 'landscape' 'landscapes' 'scene' 'symbol' 'sky'
#  'journey' 'represents' 'imagination' 'fashion' 'fantasy' 'culture' 'face'
#  'universe' 'night' 'dreams' 'living' 'place' 'earth' 'home' 'human'
#  'wall' 'archival' 'eyes' 'reflection' 'american' 'reality' 'dynamic'
#  'flowers' 'intricate' 'sense' 'music' 'nude' 'animal' 'sun' 'soul' 'girl'
#  'flower' 'space' 'evoke' 'deep' 'dance' 'emotions' 'decor' 'wonder' 'old'
#  'cotton' 'energy']
# Scores: [0.60918343 0.30205008 0.2909791  0.2711076  0.26365548 0.23816454
#  0.19373128 0.19247171 0.18911323 0.17350623 0.17195049 0.16724004
#  0.16530538 0.16342965 0.15531188 0.1551522  0.15418974 0.15276107
#  0.14710727 0.1448183  0.14369869 0.14134233 0.13221432 0.1306327
#  0.12499638 0.12492441 0.1210169  0.12090702 0.11625876 0.11261562
#  0.11192295 0.11030804 0.10614996 0.10528565 0.10425319 0.10101686
#  0.09971995 0.09965071 0.09730895 0.09667379 0.09539206 0.09388803
#  0.08753924 0.08489602 0.08446942 0.08390974 0.08192512 0.0782693
#  0.07432969 0.07285629]
#
#
# Topic 31:
# Words: ['wall' 'landscape' 'landscapes' 'decor' 'imagination' 'intricate'
#  'fantasy' 'symbol' 'dynamic' 'reflection' 'emotions' 'scene' 'space'
#  'reality' 'face' 'natural' 'evoke' 'represents' 'universe' 'heart'
#  'movement' 'dance' 'mind' 'flowers' 'archival' 'nude' 'music' 'dreams'
#  'depth' 'journey' 'flower' 'eyes' 'fashion' 'sky' 'line' 'deep' 'soul'
#  'body' 'sense' 'room' 'water' 'free' 'different' 'human' 'earth' 'self'
#  'perfect' 'street' 'living' 'culture']
# Scores: [0.45300373 0.39293122 0.3672552  0.35779345 0.35501915 0.35329974
#  0.32163495 0.31390843 0.3107009  0.2901172  0.27972588 0.27573776
#  0.26184273 0.25874633 0.25306517 0.25226286 0.2455236  0.22614703
#  0.22559296 0.22422238 0.22187677 0.21907625 0.21614769 0.2064831
#  0.20636854 0.20607796 0.20506713 0.20312235 0.20214882 0.19881514
#  0.19547287 0.18660612 0.18547766 0.1841706  0.18378326 0.17863423
#  0.17792848 0.17545912 0.17427044 0.16630885 0.16350114 0.16242388
#  0.1591669  0.15601864 0.15505476 0.15262718 0.15238309 0.14435196
#  0.14241166 0.14087977]
#
#
# Topic 32:
# Words: ['animal' 'symbol' 'face' 'eyes' 'sun' 'dance' 'human' 'evoke' 'fantasy'
#  'sky' 'earth' 'paris' 'long' 'line' 'large' 'intricate' 'represents'
#  'girl' 'night' 'wall' 'natural' 'soul' 'reflection' 'american' 'deep'
#  'flower' 'dreams' 'journey' 'old' 'hand' 'flowers' 'wonder' 'nude'
#  'young' 'cotton' 'street' 'heart' 'imagination' 'self' 'landscape'
#  'water' 'back' 'female' 'time' 'archival' 'free' 'moment' 'universe'
#  'power' 'femme']
# Scores: [0.46452242 0.2993822  0.29924178 0.2834354  0.2822832  0.28194404
#  0.28064144 0.27542457 0.2709272  0.26720887 0.25614566 0.25582987
#  0.25083393 0.2400602  0.23999022 0.239767   0.2395015  0.23902541
#  0.2386955  0.23566574 0.23236509 0.23185115 0.22902696 0.22807732
#  0.2242046  0.2225222  0.22126979 0.21941881 0.2172299  0.21228597
#  0.20287898 0.20201854 0.2016241  0.19951466 0.19894588 0.197552
#  0.19727683 0.19665335 0.19602379 0.18991876 0.18912646 0.18789673
#  0.18761548 0.18218976 0.18153039 0.17501311 0.17453995 0.17295432
#  0.17236282 0.17029883]
#
#
# Topic 33:
# Words: ['animal' 'girl' 'human' 'eyes' 'face' 'intricate' 'dance' 'fantasy'
#  'female' 'cotton' 'flowers' 'evoke' 'mind' 'flower' 'long' 'sky' 'nude'
#  'heart' 'wonder' 'dreams' 'paris' 'water' 'imagination' 'old' 'sense'
#  'body' 'landscape' 'femme' 'sun' 'wall' 'deep' 'symbol' 'look' 'earth'
#  'street' 'soul' 'natural' 'hand' 'represents' 'journey' 'home' 'self'
#  'landscapes' 'young' 'emotions' 'night' 'decor' 'music' 'large' 'feel']
# Scores: [0.5872716  0.3834318  0.38162038 0.3809672  0.3789391  0.3711996
#  0.36291146 0.36249495 0.34638378 0.3426507  0.31977078 0.31828928
#  0.3181684  0.31521344 0.31433564 0.31041986 0.30688423 0.30399787
#  0.29777247 0.29715216 0.29522753 0.2930835  0.29182404 0.29052377
#  0.28588462 0.2850207  0.28369188 0.28296375 0.27907985 0.27610907
#  0.2744646  0.27401513 0.27335793 0.27293694 0.2728583  0.2723416
#  0.2720219  0.26774246 0.26622486 0.26515752 0.26478642 0.26103523
#  0.2603375  0.25859198 0.2585416  0.25710812 0.25615466 0.25477982
#  0.24947016 0.24793825]
#
#
# Topic 34:
# Words: ['american' 'human' 'culture' 'animal' 'soul' 'natural' 'fantasy'
#  'landscape' 'dreams' 'represents' 'girl' 'landscapes' 'evoke' 'earth'
#  'self' 'imagination' 'femme' 'journey' 'home' 'symbol' 'old' 'deep'
#  'night' 'sense' 'eyes' 'female' 'universe' 'dance' 'heart' 'sun' 'free'
#  'feel' 'living' 'sky' 'emotions' 'mind' 'different' 'women' 'wonder'
#  'scene' 'nude' 'cotton' 'flowers' 'day' 'face' 'intricate' 'flower'
#  'water' 'archival' 'long']
# Scores: [0.50927967 0.2751056  0.2525944  0.23700818 0.21524881 0.2125488
#  0.21024552 0.20140879 0.20095044 0.1996117  0.19717543 0.19531476
#  0.18551797 0.18147501 0.16916488 0.1673804  0.16709822 0.16395247
#  0.16055444 0.15869534 0.15624818 0.15253678 0.14880387 0.14819822
#  0.1472778  0.14573826 0.14418197 0.14198723 0.13946939 0.1375766
#  0.13675073 0.13663611 0.13536254 0.1321381  0.12957732 0.12924086
#  0.12812893 0.12755479 0.12718716 0.12622482 0.11765279 0.11484496
#  0.11380523 0.10911824 0.10849351 0.10229766 0.10118921 0.10101325
#  0.100536   0.09897476]
#
#
# Topic 35:
# Words: ['nude' 'eyes' 'flowers' 'flower' 'decor' 'water' 'sun' 'reflection'
#  'line' 'soul' 'dance' 'intricate' 'different' 'sky' 'fashion'
#  'represents' 'cotton' 'female' 'evoke' 'landscape' 'heart' 'wall' 'face'
#  'fantasy' 'human' 'girl' 'look' 'landscapes' 'symbol' 'emotions' 'street'
#  'natural' 'music' 'deep' 'american' 'long' 'body' 'night' 'dreams'
#  'universe' 'self' 'large' 'mind' 'scene' 'hand' 'journey' 'animal'
#  'imagination' 'dynamic' 'day']
# Scores: [0.45155632 0.43647802 0.4352458  0.42679513 0.41155457 0.40227714
#  0.40072834 0.39965484 0.39732644 0.39645702 0.39502677 0.39096177
#  0.3906144  0.38941255 0.38821185 0.38243628 0.3816011  0.37947512
#  0.3789213  0.37887484 0.378586   0.37843326 0.37701344 0.37663683
#  0.37470108 0.3731046  0.37290692 0.37041268 0.36821115 0.3654086
#  0.36267388 0.36181262 0.36017096 0.3576383  0.3567608  0.35668403
#  0.35507983 0.35392904 0.35294563 0.35255355 0.3522306  0.3521182
#  0.34806275 0.34486294 0.3430879  0.34149456 0.34147543 0.3413946
#  0.3385742  0.3382498 ]
#
#
# Topic 36:
# Words: ['body' 'soul' 'heart' 'human' 'eyes' 'living' 'animal' 'earth' 'symbol'
#  'culture' 'fantasy' 'self' 'nude' 'mind' 'energy' 'movement' 'dreams'
#  'imagination' 'women' 'universe' 'female' 'natural' 'sun' 'emotions'
#  'landscapes' 'intricate' 'flowers' 'represents' 'scene' 'decor' 'dance'
#  'depth' 'femme' 'water' 'different' 'sense' 'girl' 'home' 'landscape'
#  'deep' 'flower' 'time' 'music' 'power' 'face' 'feel' 'moment' 'sky'
#  'hand' 'fashion']
# Scores: [0.79025006 0.5413035  0.46123004 0.4390986  0.4243132  0.40163893
#  0.39767346 0.39271346 0.3900821  0.38978916 0.3885958  0.38719475
#  0.37542742 0.37505633 0.37285602 0.36802322 0.3676008  0.36749876
#  0.3614355  0.35882378 0.35631484 0.35423863 0.3540333  0.35366827
#  0.35329908 0.35283446 0.34999424 0.3465433  0.34265688 0.34153423
#  0.33612853 0.33562714 0.33158195 0.32920152 0.3272189  0.32677042
#  0.32525283 0.32463354 0.3210122  0.3207302  0.32014272 0.31816405
#  0.31738997 0.31388715 0.31169307 0.31092402 0.30872092 0.30655462
#  0.30549365 0.30520937]
#
#
# Topic 37:
# Words: ['eyes' 'face' 'look' 'imagination' 'see' 'mind' 'reflection' 'heart'
#  'landscape' 'landscapes' 'sense' 'body' 'wonder' 'scene' 'soul'
#  'emotions' 'human' 'fantasy' 'evoke' 'intricate' 'dreams' 'symbol' 'deep'
#  'depth' 'represents' 'dance' 'sky' 'feel' 'energy' 'sun' 'night' 'wall'
#  'animal' 'old' 'nude' 'female' 'girl' 'femme' 'long' 'moment' 'line'
#  'natural' 'reality' 'women' 'living' 'young' 'time' 'water' 'get' 'music']
# Scores: [0.8786018  0.5767282  0.57460237 0.52310383 0.5109663  0.4847616
#  0.4788136  0.4704058  0.45725292 0.45027223 0.4455003  0.44495857
#  0.44123295 0.43051106 0.43009883 0.41964173 0.41424868 0.40903887
#  0.4057896  0.40389737 0.39968902 0.39683828 0.39222008 0.39130986
#  0.38915753 0.3882439  0.38480732 0.38417763 0.38353154 0.37801886
#  0.37585345 0.37389562 0.37304163 0.37066984 0.37025237 0.3667539
#  0.3544565  0.35431635 0.35416526 0.35127133 0.34111917 0.33601788
#  0.33358848 0.33090937 0.32900897 0.3274098  0.32718742 0.32547987
#  0.3250758  0.32387713]
#
#
# Topic 38:
# Words: ['wall' 'landscapes' 'room' 'landscape' 'reality' 'living' 'look' 'see'
#  'moment' 'flower' 'animal' 'movement' 'eyes' 'face' 'flowers' 'human'
#  'time' 'decor' 'home' 'wonder' 'archival' 'natural' 'space' 'imagination'
#  'dreams' 'day' 'represents' 'scene' 'dynamic' 'used' 'feel' 'body' 'long'
#  'emotions' 'reflection' 'get' 'universe' 'energy' 'depth' 'sense' 'night'
#  'water' 'large' 'soul' 'earth' 'back' 'fantasy' 'heart' 'intricate'
#  'mind']
# Scores: [ 0.16177785  0.14424103  0.11517555  0.11162104  0.11051086  0.10472024
#   0.08394539  0.0726255   0.06827568  0.06644331  0.06407978  0.06304584
#   0.06167722  0.05735273  0.05423047  0.05137614  0.04846773  0.04776796
#   0.03903905  0.03565498  0.03143384  0.03027843  0.02871345  0.02751533
#   0.02634787  0.02546197  0.02389508  0.0223939   0.02041617  0.01851565
#   0.01540138  0.01012113  0.00983116  0.00967077  0.00936411  0.00775592
#   0.00609594  0.00254056  0.0012879  -0.00122386 -0.00132421 -0.00303095
#  -0.00369948 -0.00387222 -0.00447052 -0.0045138  -0.00454824 -0.00691673
#  -0.00991882 -0.01296502]
#
#
# Topic 39:
# Words: ['nude' 'cotton' 'sun' 'deep' 'face' 'depth' 'water' 'landscape' 'sky'
#  'dance' 'landscapes' 'fantasy' 'hand' 'intricate' 'night' 'natural' 'old'
#  'reflection' 'evoke' 'scene' 'earth' 'flower' 'girl' 'flowers' 'dreams'
#  'body' 'street' 'line' 'look' 'long' 'used' 'heart' 'day' 'journey'
#  'wall' 'soul' 'femme' 'decor' 'large' 'fashion' 'eyes' 'time' 'wonder'
#  'self' 'female' 'american' 'living' 'home' 'symbol' 'feel']
# Scores: [0.41960692 0.38073337 0.37389007 0.37341857 0.36310998 0.3592262
#  0.33410087 0.33218443 0.31740218 0.30750898 0.30659938 0.30233607
#  0.30109638 0.29457206 0.28511006 0.27783453 0.2777214  0.27683562
#  0.27270755 0.26924855 0.268852   0.26876807 0.26762056 0.265969
#  0.2626426  0.26189908 0.25792438 0.2552998  0.25003427 0.24946609
#  0.24901667 0.24794963 0.24739167 0.2455798  0.24498534 0.24244997
#  0.24145204 0.24023499 0.23959082 0.23744681 0.23596676 0.23439367
#  0.23210779 0.23147567 0.22646853 0.22623768 0.22613549 0.22122967
#  0.2200387  0.21806431]
#
#
# Topic 40:
# Words: ['hand' 'back' 'evoke' 'intricate' 'natural' 'used' 'human' 'journey'
#  'free' 'nude' 'reflection' 'soul' 'imagination' 'face' 'flowers' 'line'
#  'get' 'dance' 'cotton' 'different' 'sun' 'wonder' 'flower' 'old'
#  'represents' 'deep' 'animal' 'feel' 'fantasy' 'self' 'perfect' 'long'
#  'time' 'street' 'water' 'sense' 'paris' 'connection' 'culture' 'moment'
#  'reality' 'eyes' 'day' 'see' 'depth' 'decor' 'night' 'girl' 'body'
#  'emotions']
# Scores: [ 0.12958659  0.09207347  0.07066755  0.06930454  0.05861823  0.05196348
#   0.04406576  0.03482443  0.03281368  0.03123926  0.02857086  0.02349029
#   0.02192351  0.01841271  0.01794229  0.0179153   0.01739795  0.01567587
#   0.01544094  0.01299033  0.01280732  0.01225912  0.00941323  0.00639187
#   0.00503199  0.00185805  0.00059182  0.00027842 -0.00024936 -0.00238994
#  -0.00265361 -0.00345776 -0.00562994 -0.006838   -0.01080691 -0.01220608
#  -0.01298919 -0.01371592 -0.01434884 -0.01549751 -0.01977232 -0.02287513
#  -0.02336313 -0.02394517 -0.02468091 -0.02840615 -0.02909329 -0.03002927
#  -0.03070685 -0.03342847]
#
#
# Topic 41:
# Words: ['perfect' 'depth' 'long' 'landscape' 'sense' 'sky' 'deep' 'intricate'
#  'wonder' 'landscapes' 'feel' 'face' 'imagination' 'large' 'dreams'
#  'fantasy' 'mind' 'evoke' 'eyes' 'reality' 'get' 'natural' 'moment'
#  'living' 'see' 'time' 'scene' 'dynamic' 'journey' 'space' 'look' 'place'
#  'different' 'body' 'culture' 'line' 'city' 'young' 'night' 'dance' 'nude'
#  'self' 'reflection' 'earth' 'soul' 'human' 'girl' 'symbol' 'old' 'water']
# Scores: [0.17582925 0.15393116 0.13227597 0.12813991 0.12590846 0.11969584
#  0.11681946 0.10941237 0.10782155 0.10552786 0.10522594 0.10343478
#  0.10336793 0.09417011 0.08537443 0.0838583  0.0828438  0.08113132
#  0.07604941 0.07435884 0.06947072 0.06433547 0.06263562 0.05767313
#  0.05685143 0.05599866 0.05317488 0.05292599 0.05286755 0.05227543
#  0.05114942 0.04971279 0.04906958 0.04800617 0.04598274 0.04057207
#  0.03422287 0.0304754  0.02978159 0.02346157 0.02296943 0.02122147
#  0.02093093 0.02083579 0.01954644 0.01766374 0.01746628 0.01711853
#  0.01689004 0.01238291]
#
#
# Topic 42:
# Words: ['room' 'large' 'nude' 'space' 'living' 'home' 'decor' 'perfect' 'dance'
#  'body' 'fashion' 'wall' 'dreams' 'female' 'place' 'night' 'reality'
#  'femme' 'used' 'intricate' 'sun' 'self' 'natural' 'scene' 'girl'
#  'fantasy' 'mind' 'human' 'universe' 'women' 'long' 'old' 'soul' 'street'
#  'imagination' 'deep' 'flower' 'animal' 'hand' 'day' 'different'
#  'movement' 'line' 'sense' 'face' 'paris' 'sky' 'culture' 'earth' 'evoke']
# Scores: [0.34093165 0.19995108 0.1938606  0.19360891 0.16564865 0.15841651
#  0.15530571 0.14088205 0.11510836 0.0876015  0.08576325 0.08070606
#  0.07881692 0.07695255 0.07537095 0.07224055 0.07058281 0.07006975
#  0.068905   0.05119214 0.04844399 0.04599122 0.04549927 0.0454213
#  0.04390838 0.04379417 0.04379145 0.04308332 0.04250034 0.03593334
#  0.03353323 0.03332249 0.0332109  0.03316113 0.03277116 0.03211783
#  0.02984169 0.02908669 0.02779363 0.02685175 0.02386075 0.02322878
#  0.02269794 0.02231344 0.02164692 0.02078826 0.01987471 0.01765333
#  0.0172946  0.01716552]
#
#
# Topic 43:
# Words: ['girl' 'femme' 'female' 'home' 'old' 'young' 'women' 'evoke' 'self'
#  'soul' 'human' 'wonder' 'face' 'living' 'american' 'earth' 'heart' 'sun'
#  'animal' 'represents' 'hand' 'mind' 'natural' 'eyes' 'body' 'street'
#  'intricate' 'sky' 'journey' 'deep' 'sense' 'wall' 'time' 'look' 'get'
#  'dance' 'reflection' 'long' 'day' 'used' 'fantasy' 'universe' 'feel'
#  'dreams' 'flower' 'nude' 'culture' 'night' 'symbol' 'emotions']
# Scores: [0.5678009  0.5407131  0.49985778 0.4669756  0.4641484  0.4583652
#  0.4520174  0.43879902 0.43360165 0.4251319  0.4236527  0.41596046
#  0.41582552 0.4151604  0.4138861  0.41025034 0.40601492 0.40356767
#  0.40233195 0.40081388 0.3985466  0.39411694 0.38555765 0.38278246
#  0.38265407 0.37573117 0.37281054 0.37065917 0.36981022 0.36333287
#  0.3624285  0.3621115  0.36095935 0.36076495 0.35778618 0.35585788
#  0.35568315 0.35531253 0.3546409  0.3542993  0.3506902  0.3494925
#  0.34689456 0.3433522  0.342466   0.3397548  0.33917838 0.33889073
#  0.33636808 0.33563733]
#
#
# Topic 44:
# Words: ['dreams' 'mind' 'reality' 'imagination' 'emotions' 'sense' 'feel' 'soul'
#  'reflection' 'represents' 'self' 'journey' 'energy' 'evoke' 'sun'
#  'living' 'natural' 'movement' 'fantasy' 'deep' 'line' 'flower' 'power'
#  'universe' 'moment' 'see' 'night' 'heart' 'place' 'eyes' 'get' 'earth'
#  'perfect' 'flowers' 'sky' 'wonder' 'room' 'symbol' 'wall' 'free' 'body'
#  'space' 'landscape' 'dance' 'look' 'face' 'landscapes' 'dynamic' 'depth'
#  'water']
# Scores: [0.22231326 0.21036348 0.20941085 0.19012299 0.17658624 0.16067742
#  0.16046974 0.16013116 0.15923211 0.14215018 0.12389283 0.12370187
#  0.11337069 0.11081391 0.11025272 0.10753188 0.10667825 0.10414302
#  0.10390443 0.10358982 0.09753862 0.09745906 0.09408163 0.09352784
#  0.09205595 0.08769475 0.08755314 0.08650336 0.08505827 0.0834643
#  0.08115206 0.07834393 0.07793522 0.07462113 0.07331518 0.06968698
#  0.06915266 0.06855519 0.06766271 0.06734714 0.06700198 0.06649518
#  0.06589843 0.06226119 0.06196469 0.06122332 0.05883021 0.05760515
#  0.05757948 0.05584504]
#
#
# Topic 45:
# Words: ['imagination' 'used' 'reflection' 'evoke' 'fantasy' 'reality' 'emotions'
#  'see' 'wonder' 'intricate' 'look' 'human' 'journey' 'different' 'dynamic'
#  'culture' 'feel' 'movement' 'sense' 'face' 'scene' 'living' 'dance'
#  'mind' 'animal' 'depth' 'deep' 'self' 'hand' 'fashion' 'landscape' 'eyes'
#  'natural' 'landscapes' 'soul' 'get' 'dreams' 'sky' 'nude' 'energy'
#  'young' 'water' 'day' 'time' 'back' 'night' 'free' 'girl' 'old'
#  'universe']
# Scores: [0.23377775 0.23160891 0.20211083 0.19039942 0.1801515  0.18012539
#  0.17861253 0.16203208 0.15217501 0.14946036 0.14150405 0.14049932
#  0.14044712 0.140136   0.13747302 0.13380885 0.13307302 0.12976876
#  0.12546277 0.12494181 0.12434186 0.11406626 0.11349675 0.11317561
#  0.10908711 0.10774584 0.10222061 0.08870593 0.08626515 0.08284903
#  0.08089404 0.07934991 0.0736835  0.07078752 0.06067808 0.0604669
#  0.05937916 0.05788565 0.05394479 0.05075751 0.05056507 0.0496042
#  0.04842417 0.04810195 0.04539378 0.042118   0.03891229 0.03255417
#  0.03251909 0.02869664]
#
#
# Topic 46:
# Words: ['archival' 'sky' 'journey' 'free' 'represents' 'evoke' 'dance' 'fantasy'
#  'soul' 'night' 'nude' 'paris' 'long' 'home' 'young' 'american' 'day'
#  'moment' 'line' 'scene' 'dreams' 'reflection' 'reality' 'girl' 'sun'
#  'dynamic' 'wonder' 'symbol' 'universe' 'movement' 'imagination' 'earth'
#  'street' 'heart' 'old' 'wall' 'living' 'back' 'flower' 'fashion'
#  'different' 'emotions' 'flowers' 'perfect' 'music' 'self' 'natural'
#  'hand' 'time' 'space']
# Scores: [0.24851853 0.22776625 0.21483593 0.20966454 0.20861317 0.19664976
#  0.19597816 0.19429286 0.18818197 0.18358052 0.17561471 0.17267959
#  0.17184381 0.1697481  0.1695785  0.16945127 0.16752179 0.16714059
#  0.16537303 0.1632269  0.16079302 0.1556133  0.15300673 0.14926003
#  0.14554593 0.1449786  0.1443823  0.14437234 0.14384973 0.14304493
#  0.14217098 0.1409271  0.14057416 0.1404098  0.14019637 0.13888052
#  0.13004912 0.1292379  0.12630934 0.12458039 0.12217642 0.12143019
#  0.11729299 0.11699212 0.11443917 0.11320071 0.11258498 0.10879061
#  0.10868058 0.10822421]
#
#
# Topic 47:
# Words: ['free' 'hand' 'self' 'nude' 'symbol' 'soul' 'human' 'evoke' 'intricate'
#  'journey' 'line' 'movement' 'dance' 'long' 'natural' 'fantasy' 'perfect'
#  'body' 'sky' 'flowers' 'street' 'imagination' 'face' 'emotions' 'wall'
#  'american' 'eyes' 'different' 'heart' 'girl' 'flower' 'represents' 'used'
#  'dreams' 'home' 'reflection' 'large' 'water' 'sense' 'earth' 'landscape'
#  'sun' 'time' 'animal' 'back' 'get' 'day' 'space' 'wonder' 'old']
# Scores: [0.5643129  0.4781838  0.25561497 0.2505228  0.24239159 0.24124205
#  0.23870261 0.23598136 0.22383738 0.22032428 0.21987888 0.217804
#  0.21443492 0.21136026 0.20729479 0.20097709 0.1966481  0.19093803
#  0.18646945 0.18286762 0.18277705 0.18126118 0.17562497 0.1753557
#  0.17300224 0.17015222 0.16905515 0.16836101 0.16653924 0.15986957
#  0.1567097  0.15210658 0.1492266  0.14409316 0.1435476  0.14312989
#  0.13989967 0.13934983 0.13601649 0.13491455 0.13308328 0.13306633
#  0.13082641 0.12966406 0.12503086 0.12217408 0.11946256 0.11922134
#  0.11895482 0.11555614]
#
#
# Topic 48:
# Words: ['imagination' 'landscapes' 'landscape' 'fantasy' 'universe' 'mind'
#  'reflection' 'sense' 'natural' 'flowers' 'reality' 'see' 'flower'
#  'emotions' 'symbol' 'eyes' 'culture' 'feel' 'paris' 'dreams' 'journey'
#  'represents' 'wonder' 'look' 'movement' 'room' 'different' 'intricate'
#  'space' 'face' 'dynamic' 'energy' 'human' 'scene' 'depth' 'moment' 'back'
#  'perfect' 'women' 'time' 'connection' 'wall' 'power' 'evoke' 'music'
#  'body' 'free' 'fashion' 'living' 'sky']
# Scores: [0.16636902 0.15676713 0.13310024 0.13283831 0.12063202 0.11469063
#  0.11372879 0.11100829 0.10794564 0.09276079 0.08711541 0.086168
#  0.08304539 0.08228058 0.08136169 0.07865479 0.07480297 0.07095898
#  0.06593063 0.06321088 0.06248322 0.06220432 0.0563879  0.05376093
#  0.05311342 0.0449379  0.04240201 0.03981238 0.03578455 0.03461415
#  0.02942161 0.02879439 0.02637284 0.02559043 0.02402673 0.02328266
#  0.02262318 0.02127864 0.02089643 0.01605169 0.01594411 0.01476139
#  0.01436899 0.01430057 0.01423252 0.01361909 0.01128639 0.00559264
#  0.00522605 0.00099698]
#
#
# Topic 49:
# Words: ['flower' 'flowers' 'eyes' 'dance' 'heart' 'landscape' 'landscapes' 'soul'
#  'face' 'imagination' 'girl' 'different' 'evoke' 'fantasy' 'fashion'
#  'reflection' 'symbol' 'emotions' 'intricate' 'natural' 'animal' 'body'
#  'dreams' 'movement' 'scene' 'sky' 'reality' 'universe' 'feel' 'sense'
#  'femme' 'moment' 'human' 'female' 'mind' 'night' 'look' 'living' 'wonder'
#  'long' 'time' 'represents' 'decor' 'women' 'nude' 'journey' 'see' 'earth'
#  'deep' 'energy']
# Scores: [0.3195725  0.30501688 0.2463312  0.23975658 0.23113157 0.22770563
#  0.21708915 0.2167469  0.21319655 0.20499401 0.20146322 0.19492891
#  0.19393638 0.1861711  0.18455493 0.18220502 0.17885071 0.17879426
#  0.17697513 0.17508808 0.17432024 0.16717666 0.16602308 0.16540667
#  0.16486901 0.16478622 0.16063717 0.1584083  0.15684561 0.15320572
#  0.1497339  0.1467618  0.1437302  0.14268488 0.14063422 0.13805056
#  0.1280467  0.12700549 0.12441531 0.12375023 0.12046878 0.11893162
#  0.11710033 0.11542334 0.11527088 0.11368156 0.1109948  0.10876425
#  0.10876121 0.10677504]
#
#
# Topic 50:
# Words: ['wonder' 'look' 'see' 'large' 'evoke' 'intricate' 'landscapes'
#  'landscape' 'face' 'sky' 'represents' 'get' 'journey' 'line' 'deep'
#  'nude' 'archival' 'flowers' 'old' 'depth' 'imagination' 'eyes'
#  'reflection' 'long' 'scene' 'used' 'symbol' 'free' 'heart' 'back'
#  'emotions' 'hand' 'fantasy' 'cotton' 'paris' 'wall' 'perfect' 'mind'
#  'feel' 'american' 'dreams' 'time' 'flower' 'night' 'moment' 'dance'
#  'city' 'day' 'street' 'fashion']
# Scores: [0.2505741  0.24860358 0.21966977 0.20873463 0.20683637 0.19541164
#  0.18559755 0.17890674 0.16242313 0.15662596 0.15630025 0.15177236
#  0.14837328 0.14666969 0.14079924 0.13928829 0.13741487 0.13254935
#  0.12800065 0.12667654 0.12117242 0.1203637  0.12004115 0.1151502
#  0.11509359 0.10811666 0.10494395 0.10212144 0.10211807 0.09739714
#  0.0965594  0.09321953 0.0918449  0.08872762 0.08768661 0.08751963
#  0.08712628 0.08650067 0.08631174 0.08584738 0.08312306 0.07999776
#  0.07885228 0.07476026 0.07458927 0.07351601 0.06710286 0.06205991
#  0.06065052 0.06009884]
#
#
# Topic 51:
# Words: ['symbol' 'intricate' 'archival' 'paris' 'emotions' 'long' 'hand' 'old'
#  'imagination' 'fantasy' 'decor' 'large' 'evoke' 'represents' 'mind'
#  'free' 'flower' 'different' 'face' 'landscapes' 'sense' 'flowers' 'heart'
#  'landscape' 'deep' 'depth' 'perfect' 'power' 'fashion' 'time' 'self'
#  'natural' 'animal' 'universe' 'feel' 'human' 'energy' 'reflection' 'eyes'
#  'women' 'back' 'wonder' 'soul' 'connection' 'moment' 'night' 'wall'
#  'street' 'reality' 'culture']
# Scores: [ 0.10100579  0.09881824  0.08129092  0.08035871  0.07860865  0.07226788
#   0.06820909  0.06173414  0.05977148  0.05292329  0.04833435  0.0447047
#   0.04344494  0.03866008  0.03331421  0.031523    0.03043179  0.02929531
#   0.02620145  0.02571323  0.02549116  0.02219283  0.02200794  0.02072021
#   0.01781791  0.01585204  0.01173583  0.01019211  0.00960129  0.00811676
#   0.00775909  0.000356   -0.00159152 -0.00428554 -0.00500077 -0.00983014
#  -0.01082989 -0.01236522 -0.01260472 -0.01303521 -0.01754808 -0.02086382
#  -0.02090239 -0.02147046 -0.02316198 -0.02318385 -0.02462514 -0.02907821
#  -0.03084509 -0.03226601]
#
#
# Topic 52:
# Words: ['paris' 'fantasy' 'reality' 'emotions' 'street' 'different' 'wonder'
#  'feel' 'energy' 'intricate' 'night' 'evoke' 'moment' 'sky' 'movement'
#  'earth' 'dynamic' 'journey' 'day' 'get' 'culture' 'city' 'see'
#  'represents' 'natural' 'nude' 'living' 'scene' 'sun' 'face' 'universe'
#  'back' 'dreams' 'time' 'perfect' 'long' 'landscapes' 'look' 'free'
#  'landscape' 'water' 'women' 'deep' 'sense' 'self' 'symbol' 'animal'
#  'reflection' 'imagination' 'large']
# Scores: [0.15464623 0.1495976  0.13414383 0.12357175 0.12326042 0.12057149
#  0.11829767 0.11684782 0.11666475 0.11164267 0.1108318  0.10786687
#  0.10624295 0.10286815 0.10020995 0.10000242 0.099698   0.09967022
#  0.09902209 0.09836102 0.09692556 0.09624905 0.09367242 0.08975437
#  0.08631604 0.08529492 0.08150684 0.0795737  0.07668674 0.07555027
#  0.07275797 0.0712072  0.06870881 0.06833199 0.06772447 0.06450916
#  0.06046069 0.05977764 0.05738593 0.05718857 0.05104866 0.04824992
#  0.04747621 0.04578881 0.0447214  0.04441547 0.04376792 0.04172328
#  0.0395274  0.03869792]
#
#
# Topic 53:
# Words: ['archival' 'intricate' 'soul' 'evoke' 'imagination' 'fantasy' 'paris'
#  'line' 'sun' 'scene' 'fashion' 'decor' 'nude' 'deep' 'american'
#  'landscape' 'body' 'journey' 'sky' 'landscapes' 'culture' 'long' 'cotton'
#  'natural' 'reflection' 'dreams' 'represents' 'flower' 'human' 'symbol'
#  'self' 'wonder' 'depth' 'flowers' 'girl' 'free' 'dance' 'hand' 'animal'
#  'old' 'universe' 'back' 'home' 'different' 'earth' 'face' 'street' 'time'
#  'music' 'large']
# Scores: [0.2553292  0.19962825 0.19651741 0.18259452 0.17706257 0.17489322
#  0.17055011 0.16725728 0.16408283 0.1631556  0.16020915 0.1587063
#  0.15789129 0.15351062 0.14635354 0.14501521 0.1416403  0.14109647
#  0.14063539 0.14019582 0.13980928 0.13804276 0.1366833  0.13474607
#  0.13388032 0.13181555 0.13084313 0.12877874 0.12874684 0.12874208
#  0.12723765 0.1257793  0.12477497 0.12396662 0.12229262 0.12185165
#  0.11666001 0.11576883 0.1151054  0.11328872 0.11286692 0.11240773
#  0.10752979 0.10567127 0.10553294 0.10358145 0.09899942 0.08974568
#  0.08766641 0.08692389]
#
#
# Topic 54:
# Words: ['animal' 'human' 'face' 'soul' 'dance' 'girl' 'heart' 'american' 'mind'
#  'dreams' 'self' 'eyes' 'paris' 'imagination' 'wonder' 'fantasy' 'evoke'
#  'home' 'natural' 'deep' 'long' 'feel' 'body' 'intricate' 'landscape'
#  'sense' 'old' 'emotions' 'look' 'female' 'living' 'music' 'femme'
#  'culture' 'sun' 'flowers' 'landscapes' 'reflection' 'different' 'young'
#  'day' 'sky' 'reality' 'flower' 'night' 'earth' 'universe' 'symbol'
#  'journey' 'large']
# Scores: [0.4871217  0.24086624 0.20456788 0.1849918  0.18133378 0.1710306
#  0.1634525  0.16188243 0.16127837 0.15945794 0.15536815 0.15160891
#  0.15150511 0.15091282 0.15066995 0.15060839 0.14969912 0.14835346
#  0.14829668 0.14470023 0.14415911 0.14122795 0.13934726 0.13914678
#  0.13789934 0.13768038 0.13550705 0.1352656  0.12796885 0.12723292
#  0.12599754 0.12534049 0.12175307 0.11917109 0.11912234 0.11864219
#  0.11816465 0.11778384 0.11638057 0.11537504 0.11300749 0.11263192
#  0.1110673  0.11003521 0.1043822  0.10234113 0.1006389  0.10020334
#  0.1001574  0.0991031 ]
#
#
# Topic 55:
# Words: ['line' 'home' 'look' 'free' 'face' 'time' 'place' 'femme' 'fantasy'
#  'hand' 'animal' 'represents' 'street' 'sky' 'nude' 'music' 'connection'
#  'back' 'room' 'see' 'body' 'get' 'decor' 'wall' 'sun' 'moment' 'living'
#  'heart' 'space' 'old' 'journey' 'imagination' 'mind' 'fashion' 'evoke'
#  'deep' 'women' 'earth' 'symbol' 'soul' 'girl' 'night' 'dance' 'self'
#  'city' 'water' 'eyes' 'day' 'dreams' 'used']
# Scores: [0.47357792 0.46090484 0.4554874  0.45254797 0.45100904 0.4361605
#  0.43590587 0.4349121  0.4319767  0.4311251  0.43083376 0.4302385
#  0.42940497 0.427625   0.42722887 0.42303342 0.4218971  0.4182168
#  0.41682786 0.41617444 0.41565573 0.41036767 0.40759692 0.40585992
#  0.405046   0.40304145 0.39928722 0.3968753  0.39486402 0.3922137
#  0.39070165 0.3898109  0.38846922 0.38833645 0.38828808 0.38246453
#  0.38232023 0.38203734 0.38187408 0.38176    0.37964833 0.37906364
#  0.37668324 0.37641853 0.37597424 0.3748846  0.36990973 0.36834532
#  0.3677517  0.3669353 ]
#
#
# Topic 56:
# Words: ['nude' 'sky' 'soul' 'american' 'paris' 'human' 'natural' 'evoke' 'free'
#  'represents' 'body' 'face' 'self' 'scene' 'living' 'sun' 'femme' 'girl'
#  'journey' 'landscapes' 'old' 'symbol' 'fantasy' 'landscape' 'earth'
#  'long' 'dynamic' 'used' 'moment' 'culture' 'hand' 'reflection' 'fashion'
#  'dreams' 'women' 'different' 'wonder' 'line' 'city' 'time' 'eyes'
#  'female' 'night' 'imagination' 'young' 'archival' 'look' 'street' 'day'
#  'heart']
# Scores: [0.21472637 0.20203355 0.1943     0.17736128 0.17553842 0.17155065
#  0.14921832 0.14181109 0.13958684 0.13671614 0.12644023 0.12447807
#  0.12192258 0.11822648 0.11629103 0.10923506 0.10230236 0.09434527
#  0.09257436 0.09193164 0.09046919 0.09001058 0.08821607 0.08603358
#  0.08408169 0.08002611 0.07981421 0.07919413 0.07760173 0.072993
#  0.0724071  0.07210033 0.07039228 0.06831975 0.06704068 0.06698187
#  0.06496324 0.06467957 0.06415294 0.06320705 0.06102572 0.05975526
#  0.05966617 0.0593062  0.05902584 0.05742825 0.05702839 0.05496234
#  0.05459972 0.05399796]
#
#
# Topic 57:
# Words: ['sense' 'feel' 'cotton' 'water' 'mind' 'archival' 'wonder' 'free' 'old'
#  'natural' 'self' 'get' 'used' 'see' 'reflection' 'human' 'day' 'perfect'
#  'hand' 'back' 'street' 'heart' 'reality' 'emotions' 'young' 'nude'
#  'different' 'sky' 'energy' 'intricate' 'look' 'women' 'culture'
#  'movement' 'deep' 'time' 'evoke' 'moment' 'dynamic' 'depth' 'city'
#  'flower' 'sun' 'earth' 'fashion' 'femme' 'night' 'girl' 'imagination'
#  'living']
# Scores: [0.17689732 0.17441222 0.1620189  0.1565039  0.1531901  0.15188558
#  0.1466923  0.1387026  0.12220362 0.12157651 0.11949266 0.11401585
#  0.1102237  0.10673761 0.1035239  0.09578121 0.09563216 0.09431183
#  0.09363984 0.09180082 0.08959745 0.08757639 0.08667862 0.08605505
#  0.08526413 0.07822673 0.07508088 0.07157733 0.07132917 0.07112967
#  0.07036587 0.06773503 0.06628152 0.06504194 0.06302412 0.05869318
#  0.0570603  0.05583997 0.05450941 0.0531478  0.05172833 0.05045983
#  0.05035043 0.04876332 0.04769627 0.04443968 0.04308567 0.04137527
#  0.04124235 0.0400156 ]
#
#
# Topic 58:
# Words: ['reflection' 'archival' 'landscapes' 'landscape' 'paris' 'mind' 'line'
#  'universe' 'city' 'reality' 'sense' 'free' 'cotton' 'feel' 'represents'
#  'day' 'street' 'women' 'culture' 'depth' 'journey' 'see' 'back' 'decor'
#  'earth' 'connection' 'look' 'body' 'emotions' 'imagination' 'space' 'get'
#  'evoke' 'moment' 'intricate' 'femme' 'sky' 'energy' 'wonder' 'symbol'
#  'sun' 'home' 'heart' 'young' 'natural' 'girl' 'nude' 'animal' 'living'
#  'self']
# Scores: [0.1302641  0.1197073  0.11506371 0.10646516 0.0998313  0.08834119
#  0.08728104 0.07657602 0.0701164  0.06769907 0.0643797  0.05876665
#  0.05846726 0.05364117 0.05152915 0.0487888  0.0419253  0.04174112
#  0.03888021 0.03786844 0.03476803 0.03329019 0.03256554 0.03253299
#  0.03130274 0.03078222 0.02923889 0.02673116 0.02491986 0.0230194
#  0.02285592 0.0222865  0.02130381 0.01984581 0.01951192 0.01943192
#  0.01851073 0.01765884 0.01553565 0.01278348 0.0125084  0.0097956
#  0.00886347 0.00876669 0.00875566 0.00596654 0.0056795  0.0053161
#  0.00459937 0.0040125 ]

# %%
model = Top2Vec.load("/content/drive/MyDrive/Uni/Digital Humanities Lab/digital humanities lab/top2vec model.model")

# Get topic numbers and sizes
topic_sizes, topic_nums = model.get_topic_sizes()

# Create a copy of the original Dataframe
topic_doc = df.copy()
# Create a DataFrame to store the topic scores for all artworks
topic_scores = pd.DataFrame(0, index=topic_doc.index, columns=topic_nums)

# Loop over each topic
for t in topic_nums:
    # Get scores for the dominant topic of all documents and update the topic_scores DataFrame
    documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=t, num_docs=topic_sizes[t])
    topic_scores.loc[document_ids,t] = document_scores

# Add the DataFrame with as many columns as topics to the copy of the dataset's DataFrame
topic_doc = topic_doc.join(topic_scores)

# Determine the dominant topic and its score for each document
topic_doc['Dominant Topic'] = topic_scores.idxmax(axis=1)
topic_doc['Score'] = topic_scores.max(axis=1)

# Add them to the original DataFrame if the score is higher than the 0.5 threshold
df['Topic'] = topic_doc['Dominant Topic'].where(topic_doc['Score'] > 0.5)
df['Score'] = topic_doc['Score'].where(topic_doc['Score'] > 0.5)

# %% [markdown]
# While the keywords reported in the topic seem repetitive and many topics might seem to overlap, the analysis of the topics through the actual artworks they were assigned to provided more insight. For instance, the following cells show examples of the artwork appearing in different topics. In topic 49, with the top 5 words - as described in the cell listing all topics - being ['flower' 'flowers' 'eyes' 'dance' and 'heart'] is actually entirely about butterflies, while topic 11 with the words ['get' 'see' 'time' 'feel' and 'moment'] contains artworks without keywords. The other two examples of topics 27 and 22 present in the tail of the dataset are respectively about pop culture figures and animals, as the list of trained topics describes in the aforementioned cell.

# %%
# Tail of the dataset's DataFrame
display(df.tail(5)[["Title", "Description", "Topic", "Score"]])
# Out:
#                              Title  \
# 6107    Zeitlose Eleganz: Ein Hase
# 6108                    Temptation
# 6109                 Amy Winehouse
# 6110       Fiat 126P C64 Pixel Art
# 6111  Jesus Escape From Guantanamo
#
#                                             Description  Topic     Score
# 6107  Die Zeichnung zeigt einen Hasen in einer leben...   22.0  0.501584
# 6108  Can you resist the temptation?The beauty desir...    1.0  0.533925
# 6109  Amy Winehouse était une chanteuse et compositr...   27.0  0.694456
# 6110                                                       NaN       NaN
# 6111  I put the title inside the work, precisely so ...    NaN       NaN

# %%
display(df[df['Topic'].isin([27])].head()[['Title', 'Description', 'Topic', 'Score']])
# Out:
#                                         Title  \
# 2194  Monica Bellucci Hollywood Actress Retro
# 2255       "Tina Turner: Energy Of The Stage"
# 2360                               Gainsbourg
# 2369                 Dernier Bus Pour Bruford
# 2395                                 Bowie Ii
#
#                                             Description  Topic     Score
# 2194  Retro art Monica Bellucci, born on September 3...   27.0  0.536951
# 2255  Das digitale Bild "Tina Turner: Energy of the ...   27.0  0.528699
# 2360  GAINSBOURG impression sur dibond brillant prêt...   27.0  0.508188
# 2369  Mr Strange (Jean-Marie Gitard) est un artiste ...   27.0  0.515874
# 2395  David Bowie: A Musical Chameleon and Icon \n \...   27.0  0.767684

# %%
display(df[df['Topic'].isin([22])].tail()[['Title', 'Description', 'Topic', 'Score']])
# Out:
#                            Title  \
# 5625             Cute Love - Pet
# 5642                   Greyhound
# 5653                  Le Sauvage
# 6005              Because I Live
# 6107  Zeitlose Eleganz: Ein Hase
#
#                                             Description  Topic     Score
# 5625  Step into the realm of Digital art with this c...   22.0  0.704750
# 5642  The elegance and grace of the greyhound. This ...   22.0  0.585914
# 5653  Une image graphique et colorée. Un chien racé,...   22.0  0.546805
# 6005  Cette œuvre a été créée suite à un questionnem...   22.0  0.588668
# 6107  Die Zeichnung zeigt einen Hasen in einer leben...   22.0  0.501584

# %%
display(df[df['Topic'].isin([49])].tail(10)[['Title', "Artist", 'Description', 'Topic', 'Score']])
# Out:
#                                Title                    Artist  \
# 4176  Lutine Aux Bulles De Papillons         Madeleine Gendron
# 4286                      Papillonne           Jérôme Baraniak
# 4441           Gazing With Butterfly             Arija Paikule
# 4518                       Paràthyro                   Lula Lp
# 4694                       Butterfly          Natalia Nozdrina
# 5448                         Boréale  Thomas Blondeau-Dumoulin
# 5451                             Bly                 Jiyonisus
# 5507           Woman And Butterflies                   Mariana
# 5769                        Contrast           Roxana Ferllini
# 6086                  Butterfly Mask      Guillaume Bellebault
#
#                                             Description  Topic     Score
# 4176                                                NaN   49.0  0.698130
# 4286  La beauté de la nature cache toujours une arme...   49.0  0.631043
# 4441  Digital art with artist's signature.\n\n      ...   49.0  0.648213
# 4518  Boho art\n\n                \n                ...   49.0  0.527753
# 4694  There are butterflies that live only a day. On...   49.0  0.648332
# 5448                                                NaN   49.0  0.673721
# 5451  It's a virtual picture made in monochromatic s...   49.0  0.633513
# 5507  Mujer y mariposas\n\n                \n       ...   49.0  0.870023
# 5769  Contrast is digital a mixed media art - \n \n*...   49.0  0.620613
# 6086  Artwork qui sera imprimé\n\n                \n...   49.0  0.801913

# %%
display(df[df['Topic'].isin([11])].tail(5)[['Title', "Artist", 'Keywords', 'Topic', 'Score']])
# Out:
#                                      Title            Artist Keywords  Topic  \
# 5961                                Lido15  Mariano Moriconi       []   11.0
# 5966                                    24              Alex       []   11.0
# 5968  Abstract Expressionism-[Vol.12]-2/12  Nabil Zeineddine       []   11.0
# 5996                                  梦幻15         Tina Liao       []   11.0
# 6003                               Angel07     Nevio Massaro       []   11.0
#
#          Score
# 5961  0.999986
# 5966  0.999986
# 5968  0.999986
# 5996  0.999986
# 6003  0.999986

# %%
display(df[df['Topic'].isin([34])][['Title', "Artist", 'Keywords', 'Topic', 'Score']])
# Out:
#                           Title           Artist  \
# 29               Shark Warriors  Shari Blackwell
# 74                     She Wolf  Shari Blackwell
# 98                 Tribal Queen   Yoalah Brinson
# 130            Beautiful Dreams  Shari Blackwell
# 183   Lofty Thoughts and Dreams  Shari Blackwell
# 212               Whale Warrior  Shari Blackwell
# 306                   Lion King  Shari Blackwell
# 337                     Freedom  Shari Blackwell
# 380                Running Free  Shari Blackwell
# 396                   Fresh Air  Shari Blackwell
# 407   Native American War Dance     Raymond york
# 420                     Lioness  Shari Blackwell
# 461     Beautiful Dreamer No. 2  Shari Blackwell
# 478                   Searching  Shari Blackwell
# 489             Lioness Warrior  Shari Blackwell
# 560          Jaguar Beauty No 2  Shari Blackwell
# 582                     Wolfing  Shari Blackwell
# 600              Ocean Warriors  Shari Blackwell
# 612     Beautiful Dreamer No. 1  Shari Blackwell
# 699          Spiritual Dreaming  Shari Blackwell
# 745           White Wolf Spirit  Shari Blackwell
# 768                      divine   darshan lawand
# 802                    Becoming  Shari Blackwell
# 822          Beautiful Dreamers  Shari Blackwell
# 861              INDIAN GODDESS     James grider
# 881                Snow Goddess  Shari Blackwell
# 1001               Tribal Queen   Yoalah Brinson
# 1036             Leopard Spirit  Shari Blackwell
# 1051                     Flying  Shari Blackwell
# 1061              Magical Horse  Shari Blackwell
# 1153                   Welcome!  Shari Blackwell
# 1217             Glorious Being  Shari Blackwell
# 1253        Jaguar Beauty No. 2  Shari Blackwell
# 1280        Shark Warriors No 2  Shari Blackwell
# 1508                Day Dreamer  Shari Blackwell
# 1570                    Pegasus  Shari Blackwell
# 1573                   Floating  Shari Blackwell
# 1680        Ocean Goddess No. 2  Shari Blackwell
# 1702       Magical Ocean Spirit  Shari Blackwell
# 1707               Snow Buffalo  Shari Blackwell
# 1749                   Drifting  Shari Blackwell
# 1822               Sand Goddess  Shari Blackwell
# 1835                Winter Pink  Shari Blackwell
# 1885               In Her Glory  Shari Blackwell
# 3033        An American History          Jesusky
# 3246      Ferocious Hermit Yogi   Dmitry Bodyaev
# 3255       Sagesse Amérindienne            Elina
# 5162           Jeweled Feathers    Christy Leigh
# 5285                      India    Sara Kouchtaf
#
#                                                Keywords  Topic     Score
# 29          [warriors, shark, indian, native, american]   34.0  0.773282
# 74                     [wolf, american, native, indian]   34.0  0.882040
# 98                     [queen, yoalah, tribal, brinson]   34.0  0.528603
# 130                  [indian, native, dreams, american]   34.0  0.840136
# 183   [dreams, indian, dreaming, thoughts, lofty, na...   34.0  0.694171
# 212          [whale, indian, warrior, native, american]   34.0  0.830724
# 306              [indian, american, king, native, lion]   34.0  0.798335
# 337                 [freedom, native, american, indian]   34.0  0.816050
# 380           [free, indian, running, native, american]   34.0  0.797650
# 396              [indian, fresh, air, native, american]   34.0  0.804803
# 407                           [dance, native, american]   34.0  0.697811
# 420                 [indian, native, lioness, american]   34.0  0.867477
# 461                 [dreamer, native, american, indian]   34.0  0.912534
# 478               [indian, native, american, searching]   34.0  0.881263
# 489        [indian, warrior, lioness, native, american]   34.0  0.800747
# 560                  [native, jaguar, american, indian]   34.0  0.862462
# 582                 [wolfing, native, american, indian]   34.0  0.886879
# 600         [warriors, indian, native, ocean, american]   34.0  0.808429
# 612                 [dreamer, native, american, indian]   34.0  0.912534
# 699     [indian, spiritual, dreaming, native, american]   34.0  0.853406
# 745            [indian, native, spirit, wolf, american]   34.0  0.887697
# 768                       [enegry, divine, god, indian]   34.0  0.731944
# 802                [native, american, becoming, indian]   34.0  0.868801
# 822                [dreamers, native, american, indian]   34.0  0.901203
# 861   [combined, indian, goddeess, get, goddess, quite]   34.0  0.600649
# 881           [snow, indian, goddess, native, american]   34.0  0.788933
# 1001                   [queen, yoalah, tribal, brinson]   34.0  0.528603
# 1036        [indian, leopard, spirit, native, american]   34.0  0.894963
# 1051                 [native, american, flying, indian]   34.0  0.855260
# 1061  [dreams, indian, magical, horse, native, ameri...   34.0  0.742368
# 1153  [love, welcome, spirit, animals, women, native...   34.0  0.630577
# 1217               [glorious, native, american, indian]   34.0  0.874922
# 1253                 [native, jaguar, american, indian]   34.0  0.862462
# 1280        [warriors, shark, indian, native, american]   34.0  0.773281
# 1508                   [dreamer, native, american, day]   34.0  0.758883
# 1570                [pegasus, native, american, indian]   34.0  0.864463
# 1573      [indian, floating, floatin, native, american]   34.0  0.677757
# 1680         [indian, goddess, native, ocean, american]   34.0  0.812083
# 1702  [indian, magical, spirit, native, ocean, ameri...   34.0  0.794220
# 1707          [snow, indian, buffalo, native, american]   34.0  0.802836
# 1749               [native, drifting, american, indian]   34.0  0.853320
# 1822          [sand, indian, goddess, native, american]   34.0  0.796795
# 1835                 [winter, native, american, indian]   34.0  0.855343
# 1885                  [glory, native, american, indian]   34.0  0.875462
# 3033             [streetart, animal, american, history]   34.0  0.500956
# 3246  [hermit, drawn, ferocious, jungle, hindustan, ...   34.0  0.566078
# 3255                            [amérindienne, sagesse]   34.0  0.604738
# 5162  [love, culture, jeweled, enjoy, feathers, nati...   34.0  0.574152
# 5285         [chakra, spiritual, elephant, india, warm]   34.0  0.524372

# %% [markdown]
# The interpretation of all 58 topics by reviewing their artworks, allowed the categorization of the modelled topics into themes, as displayed in the table below. The most common theme relates to animals, with one, as shown in the example relating specifically to butterflies. Other prevalent themes that emerge from the interpretation of topics are emotions, the representation of women, landscapes and urban contexts. At the same time, highly specific topics, such as one relating to butterflies, Native Americans, vision and sight, and the future. These topics highlight the diversity of the dataset, but also reveal how a relatively small dataset can cause skewing in topic modeling. For instance the unexpected topic regarding Native Americans likely emerged due to the presence of multiple artworks by a single artist depicting this culture, but this may not correspond to a frequent theme in digital arts. At the same time, these themes mostly seem to reflect common art subjects in traditional art, likely with some additions such as the theme regarding robots and the future, which might be more common to digital arts.

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th>Theme</th>
#             <th>Topic Number</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Landscapes</td>
#             <td>9, 10, 21, 24</td>
#         </tr>
#         <tr>
#             <td>Flowers</td>
#             <td>25</td>
#         </tr>
#         <tr>
#             <td>Sea</td>
#             <td>28, 24</td>
#         </tr>
#         <tr>
#             <td>Animals</td>
#             <td>29, 22, 33, 32, 49, 54</td>
#         </tr>
#         <tr>
#             <td>Universe</td>
#             <td>20, 26</td>
#         </tr>
#         <tr>
#             <td>Natural Elements</td>
#             <td>12, 19</td>
#         </tr>
#         <tr>
#             <td>Emotions</td>
#             <td>1, 2, 3, 6, 44</td>
#         </tr>
#         <tr>
#             <td>Native Americans</td>
#             <td>34</td>
#         </tr>
#         <tr>
#             <td>Love</td>
#             <td>16</td>
#         </tr>
#         <tr>
#             <td>Family</td>
#             <td>43</td>
#         </tr>
#         <tr>
#             <td>Music/Pop Culture</td>
#             <td>27</td>
#         </tr>
#         <tr>
#             <td>Dance</td>
#             <td>42</td>
#         </tr>
#         <tr>
#             <td>Vision</td>
#             <td>37</td>
#         </tr>
#         <tr>
#             <td>Women</td>
#             <td>4, 36, 13, 18</td>
#         </tr>
#         <tr>
#             <td>Robots/Futuristic</td>
#             <td>15</td>
#         </tr>
#         <tr>
#             <td>Urban</td>
#             <td>41, 7, 30, 52</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# This query expansion aims to improve the relevance of results by adding synonyms and meronyms to the query. This was achieved through the WordNet (2010) database. However, as synonyms are automatically added detatched from the context of the query, it may cause the query expansion to also include unrelated words.

# %%
def expand_query(query):
    """
    Expand query through synonyms and meronyms

    Args:
    query (str)

    Returns:
    list : a list containing the word(s) of the original query and its synonyms and meronyms from WordNet
    """
    tokens = nltk.word_tokenize(query)
    expanded_query = []
    expanded_query.extend(tokens)

    for token in tokens:
        synonyms = set()
        meronyms = set()
        # Add synonyms to the set
        for synonym in wordnet.synsets(token):
            for lemma in synonym.lemmas():
                if synonym.wup_similarity(wordnet.synsets(token)[0]) >= 0.6:
                    synonyms.add(lemma.name())
            # Add the meronyms to the set
            for meronym in synonym.part_meronyms():
                for lemma in meronym.lemmas():
                    meronyms.add(lemma.name())
            for meronym in synonym.substance_meronyms():
                for lemma in meronym.lemmas():
                    meronyms.add(lemma.name())
        # Add to the expanded query list
        expanded_query.extend(synonyms)
        expanded_query.extend(meronyms)

    # Remove duplicates and convert back to list
    expanded_query = list(set(expanded_query))
    return expanded_query

# %% [markdown]
# The following test cells provide an example of how this query expansion works. The inclusion of synonyms and meronyms, — words with similar meanings and parts of the queried word, respectively — aims to broaden the search. However, we can see how the synonyms of the word “cat” also include words like “caterpillar” and “vomit”, amongst others. To mitigate this problem, we introduced a similarity threshold of 0.6 for synonyms to reduce overexpansion. Despite this measure, as words are not considered in their contexts, the issue of adding irrelevant keywords can persist. On the other hand, the addition of meronyms appears effective in retrieving words from the same field, and thus relevant, such as the query “computer” expanded through “keyboard” and “microchip” and room with “wall” and “ceiling”.

# %%
for synonym in wordnet.synsets("cat"):
  print(synonym.lemmas())
# Out:
# [Lemma('cat.n.01.cat'), Lemma('cat.n.01.true_cat')]
# [Lemma('guy.n.01.guy'), Lemma('guy.n.01.cat'), Lemma('guy.n.01.hombre'), Lemma('guy.n.01.bozo')]
# [Lemma('cat.n.03.cat')]
# [Lemma('kat.n.01.kat'), Lemma('kat.n.01.khat'), Lemma('kat.n.01.qat'), Lemma('kat.n.01.quat'), Lemma('kat.n.01.cat'), Lemma('kat.n.01.Arabian_tea'), Lemma('kat.n.01.African_tea')]
# [Lemma('cat-o'-nine-tails.n.01.cat-o'-nine-tails'), Lemma('cat-o'-nine-tails.n.01.cat')]
# [Lemma('caterpillar.n.02.Caterpillar'), Lemma('caterpillar.n.02.cat')]
# [Lemma('big_cat.n.01.big_cat'), Lemma('big_cat.n.01.cat')]
# [Lemma('computerized_tomography.n.01.computerized_tomography'), Lemma('computerized_tomography.n.01.computed_tomography'), Lemma('computerized_tomography.n.01.CT'), Lemma('computerized_tomography.n.01.computerized_axial_tomography'), Lemma('computerized_tomography.n.01.computed_axial_tomography'), Lemma('computerized_tomography.n.01.CAT')]
# [Lemma('cat.v.01.cat')]
# [Lemma('vomit.v.01.vomit'), Lemma('vomit.v.01.vomit_up'), Lemma('vomit.v.01.purge'), Lemma('vomit.v.01.cast'), Lemma('vomit.v.01.sick'), Lemma('vomit.v.01.cat'), Lemma('vomit.v.01.be_sick'), Lemma('vomit.v.01.disgorge'), Lemma('vomit.v.01.regorge'), Lemma('vomit.v.01.retch'), Lemma('vomit.v.01.puke'), Lemma('vomit.v.01.barf'), Lemma('vomit.v.01.spew'), Lemma('vomit.v.01.spue'), Lemma('vomit.v.01.chuck'), Lemma('vomit.v.01.upchuck'), Lemma('vomit.v.01.honk'), Lemma('vomit.v.01.regurgitate'), Lemma('vomit.v.01.throw_up')]

# %%
query = "cat"
print(expand_query(query))
# Out:
# ['cat', 'big_cat', 'true_cat']

# %%
query = "computer"
print(expand_query(query))
# Out:
# ['bus', 'central_processing_unit', 'keyboard', 'microchip', 'CPU', 'monitoring_device', 'computer_peripheral', 'computer', 'computer_storage', 'floppy_disk', 'central_processor', 'chip', 'disk_cache', 'computer_memory', 'processor', 'silicon_chip', 'memory', 'computer_circuit', 'peripheral_device', 'information_processing_system', 'store', 'busbar', 'computing_machine', 'monitor', 'memory_board', 'hardware', 'micro_chip', 'data_converter', 'CRT', 'cathode-ray_tube', 'storage', 'diskette', 'mainframe', 'microprocessor_chip', 'computer_hardware', 'data_processor', 'computing_device', 'C.P.U.', 'peripheral', 'electronic_computer', 'floppy', 'computer_accessory']

# %%
query = "room"
print(expand_query(query))
# Out:
# ['room', 'flooring', 'wall', 'floor', 'ceiling', 'room_light']

# %%
query = "father"
print(expand_query(query))
# Out:
# ['father', 'begetter', 'sire', 'forefather', 'male_parent']

# %%
# Replace empty strings with NaN values
df = df.replace({"": np.nan})

# Convert multiple columns to numeric values
df['Dimensions in cm2'] = pd.to_numeric(df['Dimensions in cm2'], errors='coerce')
df['Height'] = pd.to_numeric(df['Height'], errors='coerce')
df['Width'] = pd.to_numeric(df['Width'], errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %% [markdown]
# This search function serves as the backend of the final tool. Given the arguments in the form of a user input it applies filters based on these arguments and returns a filtered DataFrame and mean prices. The DataFrame is sorted by Price, as the project focuses on price fairness, unless a theme filter is applied, in which case, the order depends on the topic score assigned by the trained model.
